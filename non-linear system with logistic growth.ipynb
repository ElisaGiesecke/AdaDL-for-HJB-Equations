# %% [markdown]
# ### Loading packages

# %%
import numpy as np

import torch
from torch import nn
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
# %matplotlib inline

import time
import warnings
import os

# %%
# set seed to control sources of randomness for reproducibilty
np.random.seed(1);   
torch.manual_seed(1);

# %% [markdown]
# ### Discretized example problem

# %%
import OCP

# name problem
problem_type = 'NonlinLogistic'

# choose dimension
n = 20

# choose reaction term
#rxn = None
#rxn = 'hyperbolic'
rxn = 'logistic'

# choose control term
#ctrl=None
ctrl = 'add'
#ctrl = 'bilin'

# choose indicator function for additive control
ind_fun = (0.25, 0.5)
#ind_fun = (0.25, 0.75)

# choose target
#target = OCP.zero
target = OCP.quadratic
#target = OCP.polynomial
#target = OCP.sin   
#target = OCP.quadratic_cos

# choose coefficients for system and cost
system_coeff = {'a':0.09, 'b':1., 'c':1.}
cost_coeff = {'alpha':1., 'beta':0.1, 'gamma':2.}

# choose initial and final time, 1D space and initial condition domain
#t=(0.,5.)
#Omega=(0.,1.)
#X0=(-1.5,1.5))

# initialize problem
problem = OCP.ControlledReactionDiffusionSystem(n, rxn=rxn, ctrl=ctrl, ind_fun=ind_fun, target=target, 
                                                system_coeff=system_coeff, cost_coeff=cost_coeff)

# save problem and its configurations
problem.save_config(problem_type)
problem.save_problem(problem_type)

# %% [markdown]
# ### Initial data generation

# %%
import BVP
import data_generation

# choose number of trajectories in initial training set and validation set
num_train_samples = 5 
num_val_samples = 5

# generate initial training data using time-marching
X0_samples = data_generation.sample_X0(problem, num_samples=num_train_samples)
print('------------------------------------\n Initial Training Data Generation\n------------------------------------')
with warnings.catch_warnings():
    warnings.simplefilter('once')
    t_data, X_aug_data, idx_samples, _ = BVP.solve_BVP(problem, X0_samples)
data_generation.save_data(t_data, X_aug_data, idx_samples, problem_type, 'train')

# generate validation data using time-marching
X0_samples = data_generation.sample_X0(problem, num_samples=num_val_samples)
print('------------------------------------\n Validation Data Generation\n------------------------------------')
with warnings.catch_warnings():
    warnings.simplefilter('once')
    t_data, X_aug_data, idx_samples, _ = BVP.solve_BVP(problem, X0_samples)
data_generation.save_data(t_data, X_aug_data, idx_samples, problem_type, 'val')
# Out:
# ------------------------------------
#  Initial Training Data Generation
# ------------------------------------
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 5 generating 3555 data points (from 150 initially guessed points)
# solution time:       13.565349 of which 13.564817 solving BVP
# solution time per data point: 0.003816
#
# ------------------------------------
#  Validation Data Generation
# ------------------------------------
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:94: RuntimeWarning: overflow encountered in multiply
#   R = self.b*X*(1-X)
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:181: RuntimeWarning: invalid value encountered in add
#   return 2*self.alpha*self.mesh_size * (X-Y) + self.Q.T @ P + dRdx + dSdx
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:125: RuntimeWarning: overflow encountered in square
#   return self.alpha*self.mesh_size*np.sum((X-Y)**2, axis=0, keepdims=True)
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:309: RuntimeWarning: invalid value encountered in subtract
#   0.125 * h * (f[:, 1:] - f[:, :-1]))
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:156: RuntimeWarning: invalid value encountered in matmul
#   U = -self.c/(2*self.beta) * self.ind.T @ P
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:311: RuntimeWarning: invalid value encountered in add
#   col_res = y[:, 1:] - y[:, :-1] - h / 6 * (f[:, :-1] + f[:, 1:] +
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:311: RuntimeWarning: overflow encountered in add
#   col_res = y[:, 1:] - y[:, :-1] - h / 6 * (f[:, :-1] + f[:, 1:] +
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:592: RuntimeWarning: overflow encountered in true_divide
#   t = (yp[:, :-1] + yp[:, 1:] - 2 * slope) / h
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:594: RuntimeWarning: overflow encountered in subtract
#   c[1] = (slope - yp[:, :-1]) / h - t
# /home/eg/Desktop/Masterarbeit/programs/BVP.py:122: RuntimeWarning: A singular Jacobian encountered when solving the collocation system.
#   warnings.warn(sol.message, RuntimeWarning)
# /home/eg/Desktop/Masterarbeit/programs/BVP.py:122: RuntimeWarning: The maximum number of mesh nodes is exceeded.
#   warnings.warn(sol.message, RuntimeWarning)
# number of fails:     2
# fail time:           11.819805
#
# number of solutions: 5 generating 3688 data points (from 150 initially guessed points)
# solution time:       12.844705 of which 12.844221 solving BVP
# solution time per data point: 0.003483

# %% [markdown]
# ### Neural network model

# %%
import NN

# name model
model_type = 'ResidualForcedFinalConditionNet'

# set hyperparameters
depth = 4
width = 100

#activation = nn.Tanh()        
#activation = nn.ReLU()         
activation = nn.Softplus()

#architecture = 'feedforward'  
architecture = 'residual'

# get cpu or gpu device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'using {device} device\n')

# initialize model
#model = NN.FeedforwardNet(n, depth, width, activation, device).to(device)
model = NN.NeuralNet(n, depth, width, activation, architecture, device).to(device)
model = NN.ForcedFinalConditionNet(model, problem)

# print model and its parameters
print('------------------------------------\n Neural Network Model\n------------------------------------')
print(model)
# Out:
# using cpu device
#
# ------------------------------------
#  Neural Network Model
# ------------------------------------
# ForcedFinalConditionNet(
#   (model): NeuralNet(
#     (activation): Softplus(beta=1, threshold=20)
#     (input_layer): Linear(in_features=21, out_features=100, bias=True)
#     (hidden_layers): ModuleList(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Linear(in_features=100, out_features=100, bias=True)
#       (2): Linear(in_features=100, out_features=100, bias=True)
#       (3): Linear(in_features=100, out_features=100, bias=True)
#     )
#     (output_layer): Linear(in_features=100, out_features=1, bias=True)
#   )
#   (activation): Softplus(beta=1, threshold=20)
# )

# %% [markdown]
# ### Training with adaptive data generation

# %%
import NN_optimization

# name training
train_type = 'Adam'

# initialize optimizer
#optimizer = torch.optim.SGD(model.parameters(), lr=1e-3, weight_decay=0.01)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=0.01)
#optimizer = torch.optim.LBFGS(model.parameters())

# choose batch size
batch_size = 100
#batch_size = 'full'

# choose gradient regularization weight
#grad_reg = 0.
grad_reg = 100.

# choose early stopping, data set size selection and convergence parameters
#criterion = 'GL' 
criterion = 'PQ'
#criterion = 'UP'
error_metric = [0., 0., 1.]
#error_metric = [1., grad_reg, 0.]
stop_params = {'error_metric':error_metric, 'strip':5, 'num_strips':1, 
               'max_iter':50, 'min_progress':0.01, 'criterion':criterion, 'stop_tol':0.1}
select_params = {'subset_size':None, 'conv_tol':1e-4, 'growth_ub':1.25}
max_epoch = 200
max_time = 1000.

# save partially trained models
#partial_train_times = [float('inf')]
partial_train_times = [5, 100, float('inf')] 
current_train_phase = 0
partial_train_type = train_type + 'PartialTrain' + str(partial_train_times[current_train_phase])

# initialize training and convergence
training = NN_optimization.NetTraining(optimizer, batch_size, grad_reg=grad_reg, 
                                       max_epoch=max_epoch, max_time=max_time,
                                       stop_params=stop_params, select_params=select_params)

# save model configurations
model.save_config(problem_type, model_type, train_type)

# save training configurations
training.save_config(problem_type, model_type, train_type)

# %%
start_train_time = time.time()

# loop for convergence test and data generation
while True:
    # create data set
    train_data = data_generation.OCPDataset(problem_type, 'train')
    val_data = data_generation.OCPDataset(problem_type, 'val')

    # create dataloader
    if training.batch_size == 'full':
        train_dataloader = DataLoader(train_data, batch_size=len(train_data))
        val_dataloader = DataLoader(val_data, batch_size=len(val_data))    
    else:
        train_dataloader = DataLoader(train_data, batch_size=training.batch_size, shuffle=True)
        val_dataloader = DataLoader(val_data, batch_size=training.batch_size, shuffle=True)

    # loop for training with fixed data set
    while True:
        training.current_epoch += 1
        print(f'------------------------------------\n Epoch {training.current_epoch}\n------------------------------------')
        
        # track number of training data
        num_train_data = len(train_data)
        training.num_train_data.append(num_train_data)
        
        # train model
        training.train(train_dataloader, model)
        print('')
        
        # compute relative errors
        print('training errors:')
        training.train_errors = np.hstack((training.train_errors, training.validate(train_dataloader, problem, model)))
        print('validation errors:')
        training.val_errors = np.hstack((training.val_errors, training.validate(val_dataloader, problem, model)))
        print('')
        
        # update optimal epoch and check early stopping criterion to prevent overfitting
        stop = training.early_stop()
        print('')
        
        # save model parameters of optimal epoch
        if training.opt_epoch == training.current_epoch:
            model.save_model(problem_type, model_type, train_type) 
        
        # track training time
        end_train_time = time.time()
        training.train_times.append(end_train_time - start_train_time)
        start_train_time = time.time()
        
        # save partially trained model
        if sum(training.train_times) >= partial_train_times[current_train_phase]:
            partial_train_model = NN.load_model(problem_type, model_type, train_type)
            partial_train_model.save_model(problem_type, model_type, partial_train_type) 
            current_train_phase += 1
            partial_train_type = train_type + 'PartialTrain' + str(partial_train_times[current_train_phase])
        
        # stop iterations
        if stop or training.current_epoch >= training.max_epoch or sum(training.train_times) >= training.max_time:
            training.stop_epochs.append(training.current_epoch)
            break
    
    if training.current_epoch >= training.max_epoch:
        print('Training terminated: maximum number of epochs is exceeded')
        break
        
    if sum(training.train_times) >= training.max_time:
        print('Training terminated: maximum time limit is exceeded')
        break
    
    # compute adaptive subset size for approximation of convergence criterion
    training.select_params['subset_size'] = int(100 * np.log(num_train_data/100 + 1))
    
    # select data set size
    new_num_train_data = training.select_dataset_size(train_data, model)
    training.generation_ratios.append(new_num_train_data/num_train_data)
    
    if new_num_train_data == num_train_data:
        print('Training terminated: convergence criterion is satisfied')
        break

    # generate data adaptively
    print('------------------------------------\n Adaptive Data Generation\n------------------------------------')
    # reset Adam
    #training.optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=0.01)
    while new_num_train_data > num_train_data and (sum(training.train_times) + time.time() - start_train_time) < training.max_time:
        # sample and select initial conditions with largest gradient norm
        X0_candidates = data_generation.sample_X0(problem, num_samples=10)
        X0_sample = data_generation.select_X0(problem, model, X0_candidates, num_top=1)
        
        # solve BVP with NN warm start
        solver_config = {'max_nodes':5000, 'tol':1e-5, 'replace_sample':False}
        t_data, X_aug_data, idx_samples, _ = BVP.solve_BVP(problem, X0_sample, initialization='NN_warm_start', 
                                                           init_config={'model':model}, solver_config=solver_config)
        # track number of generated data
        num_train_data += len(t_data)
        print(f'data generated: {num_train_data} / {new_num_train_data} \n')
        
        # add new data to saved data
        data_generation.update_data(t_data, X_aug_data, idx_samples, problem_type, 'train')
    
    if (sum(training.train_times) + time.time() - start_train_time) >= max_time:
        print('Training terminated: maximum time limit is exceeded')
        break

end_train_time = time.time()
training.train_times.append(end_train_time - start_train_time)
        
# save training instance
training.save_training(problem_type, model_type, train_type)
# Out:
# ------------------------------------
#  Epoch 1
# ------------------------------------
#
# generalization loss: 0.000000
#
# ------------------------------------
#  Epoch 6
# ------------------------------------
# total loss: 0.331048, value loss: 0.009174, grad loss: 0.003219 [    0/ 3555]
# total loss: 0.212287, value loss: 0.014654, grad loss: 0.001976 [ 1000/ 3555]
# total loss: 0.231239, value loss: 0.003269, grad loss: 0.002280 [ 2000/ 3555]
# total loss: 0.176168, value loss: 0.003168, grad loss: 0.001730 [ 3000/ 3555]
#
# training errors:
# value RMAE: 0.061994, grad RML1: 0.158655, ctrl RMAE: 0.060886
# validation errors:
# value RMAE: 0.113033, grad RML1: 0.334636, ctrl RMAE: 0.158805
#
# generalization loss: 0.000000
# training progress:   0.529842
#
# ------------------------------------
#  Epoch 7
# ------------------------------------
# total loss: 0.192765, value loss: 0.001917, grad loss: 0.001908 [    0/ 3555]
# total loss: 0.202805, value loss: 0.023721, grad loss: 0.001791 [ 1000/ 3555]
# total loss: 0.138165, value loss: 0.011528, grad loss: 0.001266 [ 2000/ 3555]
# total loss: 0.105734, value loss: 0.001904, grad loss: 0.001038 [ 3000/ 3555]
#
# training errors:
# value RMAE: 0.172693, grad RML1: 0.142866, ctrl RMAE: 0.058300
# validation errors:
# value RMAE: 0.162699, grad RML1: 0.325902, ctrl RMAE: 0.160294
#
# generalization loss: 0.009379
# training progress:   0.267285
#
# ------------------------------------
#  Epoch 8
# ------------------------------------
# total loss: 0.130422, value loss: 0.018710, grad loss: 0.001117 [    0/ 3555]
# total loss: 0.194383, value loss: 0.025239, grad loss: 0.001691 [ 1000/ 3555]
# total loss: 0.169526, value loss: 0.006842, grad loss: 0.001627 [ 2000/ 3555]
# total loss: 0.092188, value loss: 0.003548, grad loss: 0.000886 [ 3000/ 3555]
#
# training errors:
# value RMAE: 0.034815, grad RML1: 0.128363, ctrl RMAE: 0.052707
# validation errors:
# value RMAE: 0.104812, grad RML1: 0.318256, ctrl RMAE: 0.149109
#
# generalization loss: 0.000000
# training progress:   0.252728
#
# ------------------------------------
#  Epoch 9
# ------------------------------------
# total loss: 0.112735, value loss: 0.000782, grad loss: 0.001120 [    0/ 3555]
# total loss: 0.082945, value loss: 0.000806, grad loss: 0.000821 [ 1000/ 3555]
# total loss: 0.139420, value loss: 0.009703, grad loss: 0.001297 [ 2000/ 3555]
# total loss: 0.100761, value loss: 0.015844, grad loss: 0.000849 [ 3000/ 3555]
#
# training errors:
# value RMAE: 0.154904, grad RML1: 0.122859, ctrl RMAE: 0.052042
# validation errors:
# value RMAE: 0.227560, grad RML1: 0.311427, ctrl RMAE: 0.140333
#
# generalization loss: 0.000000
# training progress:   0.160659
#
# ------------------------------------
#  Epoch 10
# ------------------------------------
# total loss: 0.102934, value loss: 0.010189, grad loss: 0.000927 [    0/ 3555]
# total loss: 0.080215, value loss: 0.001274, grad loss: 0.000789 [ 1000/ 3555]
# total loss: 0.081805, value loss: 0.003633, grad loss: 0.000782 [ 2000/ 3555]
# total loss: 0.097719, value loss: 0.002250, grad loss: 0.000955 [ 3000/ 3555]
#
# training errors:
# value RMAE: 0.065559, grad RML1: 0.113037, ctrl RMAE: 0.051272
# validation errors:
# value RMAE: 0.133938, grad RML1: 0.301521, ctrl RMAE: 0.137583
#
# generalization loss: 0.000000
# training progress:   0.073521
#
# ------------------------------------
#  Epoch 11
# ------------------------------------
# total loss: 0.077138, value loss: 0.001806, grad loss: 0.000753 [    0/ 3555]
# total loss: 0.096322, value loss: 0.000906, grad loss: 0.000954 [ 1000/ 3555]
# total loss: 0.088556, value loss: 0.002575, grad loss: 0.000860 [ 2000/ 3555]
# total loss: 0.312485, value loss: 0.218205, grad loss: 0.000943 [ 3000/ 3555]
#
# training errors:
# value RMAE: 0.570484, grad RML1: 0.138399, ctrl RMAE: 0.063630
# validation errors:
# value RMAE: 0.644369, grad RML1: 0.324862, ctrl RMAE: 0.149491
#
# generalization loss: 0.086550
# training progress:   0.084225
#
# ------------------------------------
#  Adaptive Data Generation
# ------------------------------------
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 415 data points (from 244 initially guessed points)
# solution time:       3.202744 of which 1.063207 solving BVP
# solution time per data point: 0.007717
#
# data generated: 3970 / 4443
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 429 data points (from 243 initially guessed points)
# solution time:       3.244961 of which 1.071960 solving BVP
# solution time per data point: 0.007564
#
# data generated: 4399 / 4443
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 415 data points (from 243 initially guessed points)
# solution time:       3.117153 of which 1.047723 solving BVP
# solution time per data point: 0.007511
#
# data generated: 4814 / 4443
#
# ------------------------------------
#  Epoch 12
# ------------------------------------
# total loss: 0.613970, value loss: 0.162486, grad loss: 0.004515 [    0/ 4814]
# total loss: 0.462037, value loss: 0.018366, grad loss: 0.004437 [ 1000/ 4814]
# total loss: 0.228876, value loss: 0.029426, grad loss: 0.001994 [ 2000/ 4814]
# total loss: 0.343864, value loss: 0.057471, grad loss: 0.002864 [ 3000/ 4814]
# total loss: 0.272500, value loss: 0.005659, grad loss: 0.002668 [ 4000/ 4814]
#
# training errors:
# value RMAE: 0.044939, grad RML1: 0.172606, ctrl RMAE: 0.120938
# validation errors:
# value RMAE: 0.094380, grad RML1: 0.323103, ctrl RMAE: 0.178540
#
# generalization loss: 0.297684
# training progress:   0.328560
# ------------------------------------
#  Adaptive Data Generation
# ------------------------------------
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 426 data points (from 244 initially guessed points)
# solution time:       3.142846 of which 1.065706 solving BVP
# solution time per data point: 0.007378
#
# data generated: 5240 / 6017
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 421 data points (from 243 initially guessed points)
# solution time:       3.222123 of which 1.061050 solving BVP
# solution time per data point: 0.007653
#
# data generated: 5661 / 6017
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 439 data points (from 244 initially guessed points)
# solution time:       3.164641 of which 1.076967 solving BVP
# solution time per data point: 0.007209
#
# data generated: 6100 / 6017
#
# ------------------------------------
#  Epoch 13
# ------------------------------------
# total loss: 0.893874, value loss: 0.012762, grad loss: 0.008811 [    0/ 6100]
# total loss: 0.321599, value loss: 0.005290, grad loss: 0.003163 [ 1000/ 6100]
# total loss: 0.498501, value loss: 0.003425, grad loss: 0.004951 [ 2000/ 6100]
# total loss: 0.435612, value loss: 0.002279, grad loss: 0.004333 [ 3000/ 6100]
# total loss: 0.351450, value loss: 0.003839, grad loss: 0.003476 [ 4000/ 6100]
# total loss: 0.378414, value loss: 0.009627, grad loss: 0.003688 [ 5000/ 6100]
# total loss: 0.283179, value loss: 0.008413, grad loss: 0.002748 [ 6000/ 6100]
#
# training errors:
# value RMAE: 0.083193, grad RML1: 0.144509, ctrl RMAE: 0.061863
# validation errors:
# value RMAE: 0.106710, grad RML1: 0.293084, ctrl RMAE: 0.134821
#
# generalization loss: 0.000000
# training progress:   0.364275
#
# ------------------------------------
# value RMAE: 0.215626, grad RML1: 0.082200, ctrl RMAE: 0.026438
# validation errors:
# value RMAE: 0.298610, grad RML1: 0.194533, ctrl RMAE: 0.083960
#
# generalization loss: 0.000000
# training progress:   0.248680
#
# ------------------------------------
#  Epoch 21
# ------------------------------------
# total loss: 0.143971, value loss: 0.034694, grad loss: 0.001093 [    0/ 6100]
# total loss: 0.069743, value loss: 0.010060, grad loss: 0.000597 [ 1000/ 6100]
# total loss: 0.056004, value loss: 0.001872, grad loss: 0.000541 [ 2000/ 6100]
# total loss: 0.061642, value loss: 0.018448, grad loss: 0.000432 [ 3000/ 6100]
# total loss: 0.049366, value loss: 0.006902, grad loss: 0.000425 [ 4000/ 6100]
# total loss: 0.055349, value loss: 0.000556, grad loss: 0.000548 [ 5000/ 6100]
# total loss: 0.052568, value loss: 0.000691, grad loss: 0.000519 [ 6000/ 6100]
#
# training errors:
# value RMAE: 0.038362, grad RML1: 0.071170, ctrl RMAE: 0.029525
# validation errors:
# value RMAE: 0.060877, grad RML1: 0.178834, ctrl RMAE: 0.086331
#
# generalization loss: 0.028243
# training progress:   0.165615
#
# ------------------------------------
#  Adaptive Data Generation
# ------------------------------------
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 422 data points (from 244 initially guessed points)
# solution time:       3.106434 of which 1.112414 solving BVP
# solution time per data point: 0.007361
#
# data generated: 6522 / 7625
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 428 data points (from 245 initially guessed points)
# solution time:       3.239169 of which 1.066630 solving BVP
# solution time per data point: 0.007568
#
# data generated: 6950 / 7625
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 417 data points (from 245 initially guessed points)
# solution time:       3.211213 of which 1.064033 solving BVP
# solution time per data point: 0.007701
#
# data generated: 7367 / 7625
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 417 data points (from 243 initially guessed points)
# solution time:       3.090432 of which 1.031691 solving BVP
# solution time per data point: 0.007411
#
# data generated: 7784 / 7625
#
# ------------------------------------
#  Epoch 22
# ------------------------------------
# total loss: 0.214735, value loss: 0.002181, grad loss: 0.002126 [    0/ 7784]
# total loss: 0.209189, value loss: 0.013019, grad loss: 0.001962 [ 1000/ 7784]
# total loss: 0.931190, value loss: 0.795020, grad loss: 0.001362 [ 2000/ 7784]
# total loss: 0.533961, value loss: 0.264482, grad loss: 0.002695 [ 3000/ 7784]
# total loss: 0.191616, value loss: 0.058711, grad loss: 0.001329 [ 4000/ 7784]
# total loss: 0.123308, value loss: 0.029822, grad loss: 0.000935 [ 5000/ 7784]
# total loss: 0.111367, value loss: 0.002211, grad loss: 0.001092 [ 6000/ 7784]
# total loss: 0.098233, value loss: 0.013703, grad loss: 0.000845 [ 7000/ 7784]
#
# training errors:
# value RMAE: 0.046895, grad RML1: 0.078297, ctrl RMAE: 0.029959
# validation errors:
# value RMAE: 0.070353, grad RML1: 0.165518, ctrl RMAE: 0.075252
#
# generalization loss: 0.000000
# training progress:   0.136822
#
# ------------------------------------
#  Epoch 23
# ------------------------------------
# total loss: 0.127470, value loss: 0.001916, grad loss: 0.001256 [    0/ 7784]
# total loss: 0.121570, value loss: 0.009254, grad loss: 0.001123 [ 1000/ 7784]
# total loss: 0.129669, value loss: 0.005341, grad loss: 0.001243 [ 2000/ 7784]
# total loss: 0.062424, value loss: 0.000778, grad loss: 0.000616 [ 6000/ 9940]
# total loss: 0.059278, value loss: 0.000913, grad loss: 0.000584 [ 7000/ 9940]
# total loss: 0.035554, value loss: 0.001212, grad loss: 0.000343 [ 8000/ 9940]
# total loss: 0.079005, value loss: 0.001576, grad loss: 0.000774 [ 9000/ 9940]
#
# training errors:
# value RMAE: 0.057446, grad RML1: 0.061630, ctrl RMAE: 0.025532
# validation errors:
# value RMAE: 0.078640, grad RML1: 0.116042, ctrl RMAE: 0.039562
#
# generalization loss: 0.002364
# training progress:   0.127968
#
# ------------------------------------
#  Epoch 29
# ------------------------------------
# total loss: 0.046686, value loss: 0.002639, grad loss: 0.000440 [    0/ 9940]
# total loss: 0.046910, value loss: 0.009076, grad loss: 0.000378 [ 1000/ 9940]
# total loss: 0.066279, value loss: 0.003805, grad loss: 0.000625 [ 2000/ 9940]
# total loss: 0.078958, value loss: 0.007040, grad loss: 0.000719 [ 3000/ 9940]
# total loss: 0.086412, value loss: 0.002228, grad loss: 0.000842 [ 4000/ 9940]
# total loss: 0.115740, value loss: 0.058546, grad loss: 0.000572 [ 5000/ 9940]
# total loss: 0.054403, value loss: 0.007583, grad loss: 0.000468 [ 6000/ 9940]
# total loss: 0.039660, value loss: 0.005200, grad loss: 0.000345 [ 7000/ 9940]
# total loss: 0.118527, value loss: 0.082371, grad loss: 0.000362 [ 8000/ 9940]
# total loss: 0.046363, value loss: 0.001753, grad loss: 0.000446 [ 9000/ 9940]
#
# training errors:
# value RMAE: 0.061184, grad RML1: 0.060679, ctrl RMAE: 0.023640
# validation errors:
# value RMAE: 0.080407, grad RML1: 0.115280, ctrl RMAE: 0.043589
#
# generalization loss: 0.104411
# training progress:   0.123424
#
# ------------------------------------
#  Adaptive Data Generation
# ------------------------------------
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 421 data points (from 245 initially guessed points)
# solution time:       3.195305 of which 1.069556 solving BVP
# solution time per data point: 0.007590
#
# data generated: 10361 / 12425
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 419 data points (from 243 initially guessed points)
# solution time:       3.173000 of which 1.030224 solving BVP
# solution time per data point: 0.007573
#
# data generated: 10780 / 12425
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 452 data points (from 246 initially guessed points)
# solution time:       3.314889 of which 1.142855 solving BVP
# solution time per data point: 0.007334
#
# data generated: 11232 / 12425
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 418 data points (from 246 initially guessed points)
# solution time:       3.054516 of which 1.083688 solving BVP
# solution time per data point: 0.007307
#
# data generated: 11650 / 12425
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 420 data points (from 245 initially guessed points)
# solution time:       3.291295 of which 1.069113 solving BVP
# solution time per data point: 0.007836
#
# data generated: 12070 / 12425
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 442 data points (from 246 initially guessed points)
# solution time:       3.242066 of which 1.118471 solving BVP
# solution time per data point: 0.007335
#
# data generated: 12512 / 12425
#
# ------------------------------------
#  Epoch 30
# ------------------------------------
# total loss: 0.105316, value loss: 0.003237, grad loss: 0.001021 [    0/12512]
# total loss: 0.198251, value loss: 0.007677, grad loss: 0.001906 [ 1000/12512]
# total loss: 0.033615, value loss: 0.000998, grad loss: 0.000326 [ 2000/12512]
# total loss: 0.084211, value loss: 0.011216, grad loss: 0.000730 [ 3000/12512]
# total loss: 0.042601, value loss: 0.009206, grad loss: 0.000334 [11000/15875]
# total loss: 0.056019, value loss: 0.013013, grad loss: 0.000430 [12000/15875]
# total loss: 0.066864, value loss: 0.022076, grad loss: 0.000448 [13000/15875]
# total loss: 0.059970, value loss: 0.019067, grad loss: 0.000409 [14000/15875]
# total loss: 0.044979, value loss: 0.012115, grad loss: 0.000329 [15000/15875]
#
# training errors:
# value RMAE: 0.075051, grad RML1: 0.046543, ctrl RMAE: 0.020616
# validation errors:
# value RMAE: 0.093295, grad RML1: 0.086112, ctrl RMAE: 0.046095
#
# generalization loss: 0.167884
# training progress:   0.532778
#
# ------------------------------------
#  Adaptive Data Generation
# ------------------------------------
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 412 data points (from 243 initially guessed points)
# solution time:       3.202974 of which 1.078956 solving BVP
# solution time per data point: 0.007774
#
# data generated: 16287 / 19843
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 447 data points (from 244 initially guessed points)
# solution time:       3.357846 of which 1.094818 solving BVP
# solution time per data point: 0.007512
#
# data generated: 16734 / 19843
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 435 data points (from 243 initially guessed points)
# solution time:       3.265869 of which 1.070132 solving BVP
# solution time per data point: 0.007508
#
# data generated: 17169 / 19843
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 428 data points (from 244 initially guessed points)
# solution time:       3.343270 of which 1.078231 solving BVP
# solution time per data point: 0.007811
#
# data generated: 17597 / 19843
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 424 data points (from 245 initially guessed points)
# solution time:       3.240008 of which 1.111454 solving BVP
# solution time per data point: 0.007642
#
# data generated: 18021 / 19843
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 427 data points (from 246 initially guessed points)
# solution time:       3.364907 of which 1.101203 solving BVP
# solution time per data point: 0.007880
#
# data generated: 18448 / 19843
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 429 data points (from 245 initially guessed points)
# solution time:       3.376946 of which 1.087460 solving BVP
# solution time per data point: 0.007872
#
# data generated: 18877 / 19843
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 415 data points (from 244 initially guessed points)
# solution time:       3.322966 of which 1.073475 solving BVP
# solution time per data point: 0.008007
#
# data generated: 19292 / 19843
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 426 data points (from 244 initially guessed points)
# solution time:       3.307888 of which 1.067310 solving BVP
# solution time per data point: 0.007765
#
# data generated: 19718 / 19843
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 428 data points (from 245 initially guessed points)
# solution time:       3.287724 of which 1.093315 solving BVP
# solution time per data point: 0.007682
#
# data generated: 20146 / 19843
#
# ------------------------------------
#  Epoch 32
# ------------------------------------
# total loss: 0.044361, value loss: 0.005030, grad loss: 0.000393 [    0/20146]
# total loss: 0.046639, value loss: 0.005716, grad loss: 0.000409 [ 1000/20146]
# total loss: 0.054677, value loss: 0.020966, grad loss: 0.000337 [ 2000/20146]
# total loss: 0.047548, value loss: 0.013656, grad loss: 0.000339 [ 3000/20146]
# total loss: 0.051042, value loss: 0.010776, grad loss: 0.000403 [ 4000/20146]
# total loss: 0.067192, value loss: 0.005896, grad loss: 0.000613 [ 5000/20146]
# total loss: 0.063904, value loss: 0.012973, grad loss: 0.000509 [ 6000/20146]
# total loss: 0.031414, value loss: 0.003250, grad loss: 0.000282 [ 7000/20146]
# total loss: 0.048282, value loss: 0.003658, grad loss: 0.000446 [ 8000/20146]
# total loss: 0.047581, value loss: 0.001524, grad loss: 0.000461 [ 9000/20146]
# total loss: 0.052683, value loss: 0.001825, grad loss: 0.000509 [10000/20146]
# total loss: 0.053638, value loss: 0.001438, grad loss: 0.000522 [11000/20146]
# total loss: 0.029826, value loss: 0.004570, grad loss: 0.000253 [12000/20146]
# total loss: 0.034251, value loss: 0.003480, grad loss: 0.000308 [13000/20146]
# total loss: 0.049973, value loss: 0.008469, grad loss: 0.000415 [14000/20146]
# total loss: 0.405888, value loss: 0.352127, grad loss: 0.000538 [15000/20146]
# total loss: 0.110697, value loss: 0.052233, grad loss: 0.000585 [16000/20146]
# total loss: 0.183769, value loss: 0.104528, grad loss: 0.000792 [17000/20146]
# total loss: 0.060737, value loss: 0.007130, grad loss: 0.000536 [18000/20146]
# total loss: 0.038837, value loss: 0.004358, grad loss: 0.000345 [19000/20146]
# total loss: 0.057726, value loss: 0.016163, grad loss: 0.000416 [20000/20146]
#
# training errors:
# value RMAE: 0.033146, grad RML1: 0.049641, ctrl RMAE: 0.024830
# validation errors:
# value RMAE: 0.053349, grad RML1: 0.090915, ctrl RMAE: 0.057641
#
# generalization loss: 0.460424
# training progress:   0.476537
#
# ------------------------------------
#  Adaptive Data Generation
# ------------------------------------
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 405 data points (from 242 initially guessed points)
# solution time:       3.255049 of which 1.047731 solving BVP
# solution time per data point: 0.008037
#
# data generated: 20551 / 25182
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 436 data points (from 245 initially guessed points)
# solution time:       3.282803 of which 1.088151 solving BVP
# solution time per data point: 0.007529
#
# data generated: 20987 / 25182
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 435 data points (from 243 initially guessed points)
# solution time:       3.253011 of which 1.070552 solving BVP
# solution time per data point: 0.007478
#
# data generated: 21422 / 25182
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 433 data points (from 244 initially guessed points)
# solution time:       3.267359 of which 1.091361 solving BVP
# solution time per data point: 0.007546
#
# data generated: 21855 / 25182
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 412 data points (from 244 initially guessed points)
# solution time:       3.240311 of which 1.046858 solving BVP
# solution time per data point: 0.007865
#
# data generated: 22267 / 25182
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 423 data points (from 244 initially guessed points)
# solution time:       3.289034 of which 1.060747 solving BVP
# solution time per data point: 0.007775
#
# data generated: 22690 / 25182
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 431 data points (from 245 initially guessed points)
# solution time:       3.168658 of which 1.076751 solving BVP
# solution time per data point: 0.007352
#
# data generated: 23121 / 25182
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 433 data points (from 245 initially guessed points)
# solution time:       3.162359 of which 1.097906 solving BVP
# solution time per data point: 0.007303
#
# data generated: 23554 / 25182
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 401 data points (from 243 initially guessed points)
# solution time:       3.209121 of which 1.038519 solving BVP
# solution time per data point: 0.008003
#
# data generated: 23955 / 25182
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 412 data points (from 244 initially guessed points)
# solution time:       3.265181 of which 1.048725 solving BVP
# solution time per data point: 0.007925
#
# data generated: 24367 / 25182
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 423 data points (from 243 initially guessed points)
# solution time:       3.234691 of which 1.053752 solving BVP
# solution time per data point: 0.007647
#
# data generated: 24790 / 25182
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 449 data points (from 246 initially guessed points)
# solution time:       3.281389 of which 1.118940 solving BVP
# solution time per data point: 0.007308
#
# data generated: 25239 / 25182
#
# ------------------------------------
#  Epoch 33
# ------------------------------------
# total loss: 0.045995, value loss: 0.001264, grad loss: 0.000447 [    0/25239]
# total loss: 0.030238, value loss: 0.001402, grad loss: 0.000288 [ 1000/25239]
# total loss: 0.043683, value loss: 0.001166, grad loss: 0.000425 [ 2000/25239]
# total loss: 0.039422, value loss: 0.002153, grad loss: 0.000373 [ 3000/25239]
# total loss: 0.028104, value loss: 0.003026, grad loss: 0.000251 [ 4000/25239]
# total loss: 0.035336, value loss: 0.000973, grad loss: 0.000344 [ 5000/25239]
# total loss: 0.033749, value loss: 0.001164, grad loss: 0.000326 [ 6000/25239]
# total loss: 0.035253, value loss: 0.000984, grad loss: 0.000343 [ 7000/25239]
# total loss: 0.032662, value loss: 0.001484, grad loss: 0.000312 [ 8000/25239]
# total loss: 0.029951, value loss: 0.001646, grad loss: 0.000283 [ 9000/25239]
# total loss: 0.030484, value loss: 0.002722, grad loss: 0.000278 [10000/25239]
# total loss: 0.033498, value loss: 0.004118, grad loss: 0.000294 [11000/25239]
# total loss: 0.025102, value loss: 0.001013, grad loss: 0.000241 [12000/25239]
# total loss: 0.029761, value loss: 0.003275, grad loss: 0.000265 [13000/25239]
# total loss: 0.031712, value loss: 0.001350, grad loss: 0.000304 [14000/25239]
# total loss: 0.032371, value loss: 0.001141, grad loss: 0.000312 [15000/25239]
# total loss: 0.029002, value loss: 0.001595, grad loss: 0.000274 [16000/25239]
# total loss: 0.029243, value loss: 0.001616, grad loss: 0.000276 [17000/25239]
# total loss: 0.035512, value loss: 0.011358, grad loss: 0.000242 [18000/25239]
# total loss: 0.043025, value loss: 0.010740, grad loss: 0.000323 [19000/25239]
# total loss: 0.231128, value loss: 0.192796, grad loss: 0.000383 [20000/25239]
# total loss: 0.230933, value loss: 0.165985, grad loss: 0.000649 [21000/25239]
# total loss: 0.056007, value loss: 0.016080, grad loss: 0.000399 [22000/25239]
# total loss: 0.089164, value loss: 0.050999, grad loss: 0.000382 [23000/25239]
# total loss: 0.077587, value loss: 0.033520, grad loss: 0.000441 [24000/25239]
# total loss: 0.088539, value loss: 0.055579, grad loss: 0.000330 [25000/25239]
#
# training errors:
# value RMAE: 0.202705, grad RML1: 0.046655, ctrl RMAE: 0.021933
# validation errors:
# value RMAE: 0.258522, grad RML1: 0.087470, ctrl RMAE: 0.049360
#
# generalization loss: 0.250618
# training progress:   0.441623
#
# Training terminated: convergence criterion is satisfied

# %% [markdown]
# ### Restarting notebook

# %%
# option to restart notebook here
restart = False
if restart:
    import numpy as np
    import torch
    from torch import nn
    from torch.utils.data import DataLoader
    import matplotlib.pyplot as plt
    # %matplotlib inline
    import time
    import warnings
    import os
    
    import OCP
    import BVP
    import data_generation
    import NN
    import NN_optimization
    
    problem_type = 'NonlinLogistic'; model_type = 'ResidualForcedFinalConditionNet'; train_type = 'Adam'
    partial_train_times = [5, 100, float('inf')]
    
    problem = OCP.load_problem(problem_type)
    training = NN_optimization.load_training(problem_type, model_type, train_type)

# %% [markdown]
# ### Visualization of training phase

# %%
# plot errors, data set size and runtime in training phase
training.plot_training_phase(save=True, problem_type=problem_type, model_type=model_type, train_type=train_type)

# display training statistics
training.display_stats(save=True, problem_type=problem_type, model_type=model_type, train_type=train_type)
# Out:
# ------------------------------------
#  Training Statistics
# ------------------------------------
# total training time:           284.522766
# total number of training data: 25239
#
# data generation occured at epochs 11, 12, 21, 26, 29, 30, 31, 32 with ratio 1.249789, 1.249896, 1.250000, 1.250000, 1.250000, 1.250000, 1.249953, 1.249975
# total epochs: 33, optimal epoch: 27
#
# training errors of optimal model:
# value RMAE: 0.052259, grad RML1: 0.075039, ctrl RMAE: 0.030628
# validation errors of optimal model:
# value RMAE: 0.079673, grad RML1: 0.131633, ctrl RMAE: 0.039468

# %% [markdown]
# ### Testing  model

# %%
# choose number of trajectories in test set
num_test_samples = 10

# load optimal model parameters
model = NN.load_model(problem_type, model_type, train_type)

# generate test data using NN warm start
X0_samples = data_generation.sample_X0(problem, num_samples=num_test_samples)
print('------------------------------------\n Test Data Generation\n------------------------------------')
with warnings.catch_warnings():
    warnings.simplefilter('once')
    t_data, X_aug_data, idx_samples, _ = BVP.solve_BVP(problem, X0_samples, initialization='NN_warm_start', 
                                                       init_config={'model':model})
data_generation.save_data(t_data, X_aug_data, idx_samples, problem_type, 'test')

# compute test accuracy
test_data = data_generation.OCPDataset(problem_type, 'test')
if training.batch_size == 'full':
    test_dataloader = DataLoader(test_data, batch_size=len(test_data))
else:
    test_dataloader = DataLoader(test_data, batch_size=training.batch_size, shuffle=True)
print('------------------------------------\n Test Statistics\n------------------------------------')
print('test errors of optimal model:')
training.test_errors = np.hstack((training.test_errors, training.validate(test_dataloader, problem, model)))
training.add_test_stats(problem_type=problem_type, model_type=model_type, train_type=train_type)
# Out:
# ------------------------------------
#  Test Data Generation
# ------------------------------------
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 10 generating 4307 data points (from 2447 initially guessed points)
# solution time:       32.751353 of which 10.968208 solving BVP
# solution time per data point: 0.007604
#
# ------------------------------------
#  Test Statistics
# ------------------------------------
# test errors of optimal model:
# value RMAE: 0.066285, grad RML1: 0.139088, ctrl RMAE: 0.036498

# %% [markdown]
# ### Properties of data sets

# %%
# display properties of data sets
print('------------------------------------\n Training Data Set\n------------------------------------')
data_generation.add_dataset_stats(problem_type, 'train', save=True, model_type=model_type, train_type=train_type)

print('------------------------------------\n Validation Data Set\n------------------------------------')
data_generation.add_dataset_stats(problem_type, 'val', save=True, model_type=model_type, train_type=train_type)

print('------------------------------------\n Test Data Set\n------------------------------------')
data_generation.add_dataset_stats(problem_type, 'test', save=True, model_type=model_type, train_type=train_type)
# Out:
# ------------------------------------
#  Training Data Set
# ------------------------------------
# number of trajectories: 56, number of data points: 25239
#
# ------------------------------------
#  Validation Data Set
# ------------------------------------
# number of trajectories: 5, number of data points: 3688
#
# ------------------------------------
#  Test Data Set
# ------------------------------------
# number of trajectories: 10, number of data points: 4307

# %% [markdown]
# ### Simulation of NN, BVP, LQR solutions and uncontrolled system for specific initial condition

# %%
# name specific initial condition
init_type = 'quadcos'

# choose specific initial condition
#initial_condition = OCP.zero
#initial_condition = OCP.quadratic
#initial_condition = OCP.polynomial
#initial_condition = OCP.sin
initial_condition = OCP.quadratic_cos

# option to multiply initial condition with factor (scale or flip sign)
scale_factor = 1.

specific_X0 = scale_factor * initial_condition(problem.Omega_mesh[1:-1]).reshape(-1,1)

# get target
Y = problem.target(problem.Omega_mesh[1:-1]).reshape(-1,1)

# decide on methods for comparison (bilinear control does not allow for LQR)
methods = ['NN', 'LQR', 'BVP', 'unctrl'] 
if problem.ctrl == 'bilin' and 'LQR' in methods:
    methods.remove('LQR')

# %%
import NN_evaluation
import LQR
import simulation

# compute closed-loop NN solution
if 'NN' in methods:
    t_NN, X_NN = NN_evaluation.get_trajectory(problem, model, specific_X0)
    V_NN, P_NN, U_NN = NN_evaluation.get_data(model, t_NN, X_NN, get_U=True, problem=problem)

# compute closed-loop LQR solution
if 'LQR' in methods:
    if problem.target == OCP.zero:
        LQ_problem = LQR.LQProblem(problem)
    else:
        LQ_problem = LQR.LQProblemNonzeroTarget(problem)
    t_LQR, X_LQR = LQ_problem.get_trajectory(specific_X0)
    V_LQR, P_LQR, U_LQR = LQ_problem.get_data(t_LQR, X_LQR)
    
# compute open-loop BVP solution
if 'BVP' in methods:
    print('------------------------------------\n Specific Example Data Generation\n------------------------------------') 
    solver_config = {'max_nodes':5000, 'tol':1e-5, 'replace_sample':False}
    t_BVP, X_aug_BVP, _, X_aug_funs = BVP.solve_BVP(problem, specific_X0, initialization='NN_warm_start',
                                            init_config={'model':model}, solver_config=solver_config)
    X_BVP, V_BVP, P_BVP, U_BVP = data_generation.split_data(X_aug_BVP, get_U=True, problem=problem)
    
# compute uncontrolled dynamics 
if 'unctrl' in methods:
    ctrl = problem.ctrl
    problem.ctrl = None  
    print('--- Uncontrolled System ---')
    init_config = {'timeseq':np.array([0, 1e-03, 1e-02, .1, .125, .15, .2, .3, .4, .5, .6, .7, .8, .9, 1.])}
    solver_config = {'max_nodes':5000, 'tol':1e-5, 'replace_sample':False}
    t_unctrl, X_aug_unctrl, _, _ = BVP.solve_BVP(problem, specific_X0, initialization='time_marching', 
                                                 init_config=init_config, solver_config=solver_config)
    X_unctrl, V_unctrl, P_unctrl, U_unctrl = data_generation.split_data(X_aug_unctrl, get_U=True, problem=problem)
    if not len(t_unctrl):
        methods.remove('unctrl')
    problem.ctrl = ctrl
# Out:
# ------------------------------------
#  Specific Example Data Generation
# ------------------------------------
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 337 data points (from 240 initially guessed points)
# solution time:       3.121034 of which 0.953829 solving BVP
# solution time per data point: 0.009261
#
# --- Uncontrolled System ---
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:94: RuntimeWarning: overflow encountered in multiply
#   R = self.b*X*(1-X)
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:173: RuntimeWarning: overflow encountered in multiply
#   dRdx = self.b*P*(1-2*X)
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:125: RuntimeWarning: overflow encountered in square
#   return self.alpha*self.mesh_size*np.sum((X-Y)**2, axis=0, keepdims=True)
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:312: RuntimeWarning: overflow encountered in multiply
#   4 * f_middle)
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:566: RuntimeWarning: invalid value encountered in true_divide
#   r_middle /= 1 + np.abs(f_middle)
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:567: RuntimeWarning: invalid value encountered in true_divide
#   r1 /= 1 + np.abs(f1)
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:568: RuntimeWarning: invalid value encountered in true_divide
#   r2 /= 1 + np.abs(f2)
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:40: RuntimeWarning: invalid value encountered in subtract
#   df_dy[:, i, :] = (f_new - f0) / hi
# number of fails:     1
# fail time:           2.184040
#
# number of solutions: 0 generating 0 data points (from 0 initially guessed points)
# solution time:       0.000000 of which 0.000000 solving BVP
# solution time per data point: nan
# /home/eg/Desktop/Masterarbeit/programs/BVP.py:81: RuntimeWarning: A singular Jacobian encountered when solving the collocation system.
#   warnings.warn(sol.message, RuntimeWarning)
# /home/eg/Desktop/Masterarbeit/programs/BVP.py:165: RuntimeWarning: invalid value encountered in double_scalars
#   print(f'solution time per data point: {np.sum(solution_times)/len(t_data):<7f}\n')

# %%
# create directory for saving results
directory = simulation.get_directory(problem_type, model_type, train_type, init_type)

# plot optimal state trajectory
fig = plt.figure()
fig.suptitle('Optimal state trajectory', y=0.9)
axs = []
for num, method in enumerate(methods):                         
    axs.append(fig.add_subplot(1, len(methods), num + 1, projection='3d'))
    simulation.plot_X(eval('t_' + method), problem.Omega_mesh, eval('X_' + method), ax=axs[num])
    axs[num].set_title(method)
    axs[num].set_zlim(-1.,1.)
plt.subplots_adjust(left=0., bottom=0., right=1., top=1., wspace=0.6, hspace=0.0)
plt.savefig(directory + '/state.png', bbox_inches='tight')
plt.show()

# plot optimal costate trajectory
fig = plt.figure()
fig.suptitle('Optimal costate trajectory', y=0.9)
axs = []
for num, method in enumerate(methods):                         
    axs.append(fig.add_subplot(1, len(methods), num + 1, projection='3d'))
    simulation.plot_P(eval('t_' + method), problem.Omega_mesh, eval('P_' + method), ax=axs[num])
    axs[num].set_title(method)
    axs[num].set_zlim(-0.2,0.2)
plt.subplots_adjust(left=0., bottom=0., right=1., top=1., wspace=0.6, hspace=0.0)
plt.savefig(directory + '/costate.png', bbox_inches='tight')
plt.show()

# plot optimal control
fig = plt.figure()
fig.suptitle('Optimal control')
for method in methods:                         
    simulation.plot_U(eval('t_' + method), eval('U_' + method), label=method)
#plt.ylim(bottom=-5)
plt.legend()
plt.savefig(directory + '/control.png')
plt.show()

# plot value function along optimal state trajectory 
fig = plt.figure()
fig.suptitle('Value function along optimal state trajectory')
for method in methods:                         
    simulation.plot_V(eval('t_' + method), eval('V_' + method), label=method)
#plt.ylim(top=2.5)
plt.legend()
plt.savefig(directory + '/value_function.png')
plt.show()

# plot running cost resulting from optimal control and state trajectory 
fig = plt.figure()
fig.suptitle('Running cost resulting from optimal control and state trajectory', y=1.03)
for num, method in enumerate(methods):                         
    simulation.plot_running_cost(problem, eval('t_' + method), eval('U_' + method), eval('X_' + method), Y, 
                                 color='C' + str(num), label=method)
#plt.ylim(-1,5)
legend = plt.legend()
solid_line, = plt.plot([0],linestyle='-', color='gray')
dashed_line, = plt.plot([0],linestyle='--', color='gray')
dotted_line, = plt.plot([0],linestyle=':', color='gray')
legend_lines = plt.legend([solid_line, dashed_line, dotted_line], ['total running cost', 'running state cost', 'running control cost'], 
                          bbox_to_anchor=(0, 1.01, 1, 0.2), loc='lower left', mode='expand', borderaxespad=0, ncol=3)
plt.gca().add_artist(legend)
plt.gca().add_artist(legend_lines)
plt.savefig(directory + '/running_cost.png')
plt.show()

# display costs
for num, method in enumerate(methods): 
    append = False if num == 0 else True
    simulation.display_costs(problem, eval('t_' + method), eval('U_' + method), eval('X_' + method), Y, 
                             method=method, save=True, append=append, 
                             problem_type=problem_type, model_type=model_type, train_type=train_type, init_type=init_type)
# Out:
# ------------------------------------
#  Costs of NN Solution
# ------------------------------------
# running state cost:   1.181642
# running control cost: 1.170442
# total running cost:   2.352084
# final cost:           0.102185
# total cost:           2.454270
#
# ------------------------------------
#  Costs of LQR Solution
# ------------------------------------
# running state cost:   1.248959
# running control cost: 1.119152
# total running cost:   2.368111
# final cost:           0.106272
# total cost:           2.474383
#
# ------------------------------------
#  Costs of BVP Solution
# ------------------------------------
# running state cost:   1.213098
# running control cost: 1.139022
# total running cost:   2.352121
# final cost:           0.099875
# total cost:           2.451996

# %% [markdown]
# ### Testing BVP initialization for data generation

# %%
# sample initial conditions
X0_samples = data_generation.sample_X0(problem, num_samples=100)
solver_config = {'max_nodes':5000, 'tol':1e-5, 'replace_sample':False}

# test simple initialization
print('------------------------------------\n Simple Initialization\n------------------------------------')
_ = BVP.solve_BVP(problem, X0_samples, solver_config=solver_config)
#print('\n--- Increased time steps ---')
#_ = BVP.solve_BVP(problem, X0_samples, init_config={'timesteps':100}, solver_config=solver_config)

# test time-marching
print('------------------------------------\n Time-Marching\n------------------------------------')
_ = BVP.solve_BVP(problem, X0_samples, initialization='time_marching', solver_config=solver_config)
print('\n--- Adaptive time sequence ---')
_ = BVP.solve_BVP(problem, X0_samples, initialization='time_marching', 
                  init_config={'timeseq':np.array([0, 1e-03, 1e-02, .1, .125, .15, .2, .3, .4, .5, .6, .7, .8, .9, 1.])}, 
                  solver_config=solver_config)
print('\n--- Equidistant time sequences with increased time steps ---')
_ = BVP.solve_BVP(problem, X0_samples, initialization='time_marching', 
                  init_config={'timeseq':30}, solver_config=solver_config)
#print('\n--- Equidistant time sequences with decreased time steps ---')
#_ = BVP.solve_BVP(problem, X0_samples, initialization='time_marching', 
#                  init_config={'timeseq':5}, solver_config=solver_config)

# test NN warm start
print('------------------------------------\n NN Warm Start\n------------------------------------') 
_ = BVP.solve_BVP(problem, X0_samples, initialization='NN_warm_start', 
                  init_config={'model':model}, solver_config=solver_config)

# test NN warm start with partially trained models
for partial_train_time in partial_train_times[:-1]:
    partial_train_type = train_type + 'PartialTrain' + str(partial_train_time)
    directory = NN.get_directory(problem_type, model_type, partial_train_type, make=False)
    if os.path.exists(directory):
        print(f'\n--- Partially trained model after time {partial_train_time} ---')
        partial_train_model = NN.load_model(problem_type, model_type, partial_train_type)
        _ = BVP.solve_BVP(problem, X0_samples, initialization='NN_warm_start', init_config={'model':partial_train_model}, solver_config=solver_config)
# Out:
# ------------------------------------
#  Simple Initialization
# ------------------------------------
# /home/eg/Desktop/Masterarbeit/programs/BVP.py:122: RuntimeWarning: The maximum number of mesh nodes is exceeded.
#   warnings.warn(sol.message, RuntimeWarning)
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:129: RuntimeWarning: overflow encountered in square
#   return self.beta*U**2
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:309: RuntimeWarning: invalid value encountered in subtract
#   0.125 * h * (f[:, 1:] - f[:, :-1]))
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:156: RuntimeWarning: invalid value encountered in matmul
#   U = -self.c/(2*self.beta) * self.ind.T @ P
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:104: RuntimeWarning: invalid value encountered in matmul
#   return self.Q @ X + R + S
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:104: RuntimeWarning: invalid value encountered in add
#   return self.Q @ X + R + S
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:181: RuntimeWarning: invalid value encountered in matmul
#   return 2*self.alpha*self.mesh_size * (X-Y) + self.Q.T @ P + dRdx + dSdx
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:181: RuntimeWarning: invalid value encountered in add
#   return 2*self.alpha*self.mesh_size * (X-Y) + self.Q.T @ P + dRdx + dSdx
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:311: RuntimeWarning: overflow encountered in add
#   col_res = y[:, 1:] - y[:, :-1] - h / 6 * (f[:, :-1] + f[:, 1:] +
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:311: RuntimeWarning: invalid value encountered in add
#   col_res = y[:, 1:] - y[:, :-1] - h / 6 * (f[:, :-1] + f[:, 1:] +
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:145: RuntimeWarning: overflow encountered in square
#   return self.gamma*self.mesh_size*np.sum((X_tf-Y)**2)
# /home/eg/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:37: RuntimeWarning: invalid value encountered in add
#   y_new[i] += h[i]
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:38: RuntimeWarning: invalid value encountered in subtract
#   hi = y_new[i] - y[i]
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:88: RuntimeWarning: invalid value encountered in subtract
#   dbc_dya[i] = (bc_new - bc0) / hi
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:98: RuntimeWarning: invalid value encountered in subtract
#   dbc_dyb[i] = (bc_new - bc0) / hi
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:592: RuntimeWarning: overflow encountered in add
#   t = (yp[:, :-1] + yp[:, 1:] - 2 * slope) / h
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:592: RuntimeWarning: invalid value encountered in add
#   t = (yp[:, :-1] + yp[:, 1:] - 2 * slope) / h
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:592: RuntimeWarning: overflow encountered in true_divide
#   t = (yp[:, :-1] + yp[:, 1:] - 2 * slope) / h
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:593: RuntimeWarning: overflow encountered in true_divide
#   c[0] = t / h
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:594: RuntimeWarning: overflow encountered in true_divide
#   c[1] = (slope - yp[:, :-1]) / h - t
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:594: RuntimeWarning: overflow encountered in subtract
#   c[1] = (slope - yp[:, :-1]) / h - t
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:594: RuntimeWarning: invalid value encountered in subtract
#   c[1] = (slope - yp[:, :-1]) / h - t
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:563: RuntimeWarning: invalid value encountered in subtract
#   r1 = y1_prime - f1
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:564: RuntimeWarning: invalid value encountered in subtract
#   r2 = y2_prime - f2
# /home/eg/Desktop/Masterarbeit/programs/BVP.py:122: RuntimeWarning: A singular Jacobian encountered when solving the collocation system.
#   warnings.warn(sol.message, RuntimeWarning)
# number of fails:     9
# fail time:           75.533902
#
# number of solutions: 91 generating 30124 data points (from 2730 initially guessed points)
# solution time:       94.517124 of which 94.507671 solving BVP
# solution time per data point: 0.003138
#
# ------------------------------------
#  Time-Marching
# ------------------------------------
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 100 generating 41162 data points (from 36818 initially guessed points)
# solution time:       827.422858 of which 174.497692 solving BVP
# solution time per data point: 0.020102
#
#
# --- Adaptive time sequence ---
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 100 generating 40305 data points (from 35879 initially guessed points)
# solution time:       779.327220 of which 169.955931 solving BVP
# solution time per data point: 0.019336
#
#
# --- Equidistant time sequences with increased time steps ---
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 100 generating 69199 data points (from 65575 initially guessed points)
# solution time:       3423.269141 of which 253.959455 solving BVP
# solution time per data point: 0.049470
#
# ------------------------------------
#  NN Warm Start
# ------------------------------------
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 100 generating 42872 data points (from 24462 initially guessed points)
# solution time:       316.886652 of which 104.847444 solving BVP
# solution time per data point: 0.007391
#
#
# --- Partially trained model after time 5 ---
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 100 generating 42852 data points (from 24457 initially guessed points)
# solution time:       317.801470 of which 104.831758 solving BVP
# solution time per data point: 0.007416
#
#
# --- Partially trained model after time 100 ---
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 100 generating 42872 data points (from 24462 initially guessed points)
# solution time:       326.828108 of which 106.808556 solving BVP
# solution time per data point: 0.007623
