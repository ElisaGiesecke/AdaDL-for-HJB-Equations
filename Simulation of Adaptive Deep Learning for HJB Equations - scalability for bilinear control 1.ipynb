# %% [markdown]
# ### Loading packages

# %%
import numpy as np

import torch
from torch import nn
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
# %matplotlib inline

import time
import warnings
import os

# %%
# set seed to control sources of randomness for reproducibilty
np.random.seed(5);   
torch.manual_seed(5);

# %% [markdown]
# ### Discretized example problem

# %%
import OCP

# name problem
problem_type = 'HighDimBilinCtrlZeroTarget'

# choose dimension
n = 40

# choose reaction term
#rxn = None
rxn = 'hyperbolic'
#rxn = 'logistic'

# choose control term
#ctrl=None
#ctrl = 'add'
ctrl = 'bilin'

# choose indicator function for additive control
#ind_fun = (0.25, 0.5)
#ind_fun = (0.25, 0.75)

# choose target
target = OCP.zero
#target = OCP.quadratic
#target = OCP.polynomial
#target = OCP.sin   
#target = OCP.quadratic_cos

# choose coefficients for system and cost
system_coeff = {'a':0.02, 'b':1., 'c':1.}
cost_coeff = {'alpha':1., 'beta':0.1, 'gamma':2.}

# choose initial and final time, 1D space and initial condition domain
#t=(0.,5.)
#Omega=(0.,1.)
#X0=(-1.5,1.5))

# initialize problem
problem = OCP.ControlledReactionDiffusionSystem(n, rxn=rxn, ctrl=ctrl, target=target, 
                                                system_coeff=system_coeff, cost_coeff=cost_coeff)

# save problem and its configurations
problem.save_config(problem_type)
problem.save_problem(problem_type)

# %% [markdown]
# ### Initial data generation

# %%
import BVP
import data_generation

# choose number of trajectories in initial training set and validation set
num_train_samples = 5 
num_val_samples = 5

# choose time-marching sequence
init_config = {'timeseq':np.array([0, 1e-03, 1e-02, .1, .125, .15, .2, .3, .4, .5, .6, .7, .8, .9, 1.])}

# generate initial training data using time-marching
X0_samples = data_generation.sample_X0(problem, num_samples=num_train_samples)
print('------------------------------------\n Initial Training Data Generation\n------------------------------------')
with warnings.catch_warnings():
    warnings.simplefilter('once')
    t_data, X_aug_data, idx_samples, _ = BVP.solve_BVP(problem, X0_samples, initialization='time_marching', 
                                                       init_config=init_config)
data_generation.save_data(t_data, X_aug_data, idx_samples, problem_type, 'train')

# generate validation data using time-marching
X0_samples = data_generation.sample_X0(problem, num_samples=num_val_samples)
print('------------------------------------\n Validation Data Generation\n------------------------------------')
with warnings.catch_warnings():
    warnings.simplefilter('once')
    t_data, X_aug_data, idx_samples, _ = BVP.solve_BVP(problem, X0_samples, initialization='time_marching', 
                                                       init_config=init_config)
data_generation.save_data(t_data, X_aug_data, idx_samples, problem_type, 'val')
# Out:
# ------------------------------------
#  Initial Training Data Generation
# ------------------------------------
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 5 generating 1261 data points (from 1173 initially guessed points)
# solution time:       22.264950 of which 4.215861 solving BVP
# solution time per data point: 0.017657
#
# ------------------------------------
#  Validation Data Generation
# ------------------------------------
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 5 generating 1255 data points (from 1172 initially guessed points)
# solution time:       23.225951 of which 4.234102 solving BVP
# solution time per data point: 0.018507

# %% [markdown]
# ### Neural network model

# %%
import NN

# name model
model_type = 'ResidualForcedFinalConditionNet'

# set hyperparameters
depth = 4
width = 100

#activation = nn.Tanh()        
#activation = nn.ReLU()         
activation = nn.Softplus()

#architecture = 'feedforward'  
architecture = 'residual'

# get cpu or gpu device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'using {device} device\n')

# initialize model
#model = NN.FeedforwardNet(n, depth, width, activation, device).to(device)
model = NN.NeuralNet(n, depth, width, activation, architecture, device).to(device)
model = NN.ForcedFinalConditionNet(model, problem)

# print model and its parameters
print('------------------------------------\n Neural Network Model\n------------------------------------')
print(model)
# Out:
# using cpu device
#
# ------------------------------------
#  Neural Network Model
# ------------------------------------
# ForcedFinalConditionNet(
#   (model): NeuralNet(
#     (activation): Softplus(beta=1, threshold=20)
#     (input_layer): Linear(in_features=41, out_features=100, bias=True)
#     (hidden_layers): ModuleList(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Linear(in_features=100, out_features=100, bias=True)
#       (2): Linear(in_features=100, out_features=100, bias=True)
#       (3): Linear(in_features=100, out_features=100, bias=True)
#     )
#     (output_layer): Linear(in_features=100, out_features=1, bias=True)
#   )
#   (activation): Softplus(beta=1, threshold=20)
# )

# %% [markdown]
# ### Training with adaptive data generation

# %%
import NN_optimization

# name training
train_type = 'AdamTimeStopped'

# initialize optimizer
#optimizer = torch.optim.SGD(model.parameters(), lr=1e-3, weight_decay=0.01)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=0.01)
#optimizer = torch.optim.LBFGS(model.parameters())

# choose batch size
batch_size = 100
#batch_size = 'full'

# choose gradient regularization weight
#grad_reg = 0.
grad_reg = 100.

# choose early stopping, data set size selection and convergence parameters
#criterion = 'GL' 
criterion = 'PQ'
#criterion = 'UP'
error_metric = [0., 0., 1.]
#error_metric = [1., grad_reg, 0.]
stop_params = {'error_metric':error_metric, 'strip':5, 'num_strips':1, 
               'max_iter':50, 'min_progress':0.01, 'criterion':criterion, 'stop_tol':0.1}
select_params = {'subset_size':None, 'conv_tol':1e-4, 'growth_ub':1.25}
max_epoch = 200
max_time = 100.

# save partially trained models
partial_train_times = [float('inf')]
#partial_train_times = [5, 100, float('inf')] 
current_train_phase = 0
partial_train_type = train_type + 'PartialTrain' + str(partial_train_times[current_train_phase])

# initialize training and convergence
training = NN_optimization.NetTraining(optimizer, batch_size, grad_reg=grad_reg, 
                                       max_epoch=max_epoch, max_time=max_time,
                                       stop_params=stop_params, select_params=select_params)

# save model configurations
model.save_config(problem_type, model_type, train_type)

# save training configurations
training.save_config(problem_type, model_type, train_type)

# %%
start_train_time = time.time()

# loop for convergence test and data generation
while True:
    # create data set
    train_data = data_generation.OCPDataset(problem_type, 'train')
    val_data = data_generation.OCPDataset(problem_type, 'val')

    # create dataloader
    if training.batch_size == 'full':
        train_dataloader = DataLoader(train_data, batch_size=len(train_data))
        val_dataloader = DataLoader(val_data, batch_size=len(val_data))    
    else:
        train_dataloader = DataLoader(train_data, batch_size=training.batch_size, shuffle=True)
        val_dataloader = DataLoader(val_data, batch_size=training.batch_size, shuffle=True)

    # loop for training with fixed data set
    while True:
        training.current_epoch += 1
        print(f'------------------------------------\n Epoch {training.current_epoch}\n------------------------------------')
        
        # track number of training data
        num_train_data = len(train_data)
        training.num_train_data.append(num_train_data)
        
        # train model
        training.train(train_dataloader, model)
        print('')
        
        # compute relative errors
        print('training errors:')
        training.train_errors = np.hstack((training.train_errors, training.validate(train_dataloader, problem, model)))
        print('validation errors:')
        training.val_errors = np.hstack((training.val_errors, training.validate(val_dataloader, problem, model)))
        print('')
        
        # update optimal epoch and check early stopping criterion to prevent overfitting
        stop = training.early_stop()
        print('')
        
        # save model parameters of optimal epoch
        if training.opt_epoch == training.current_epoch:
            model.save_model(problem_type, model_type, train_type) 
        
        # track training time
        end_train_time = time.time()
        training.train_times.append(end_train_time - start_train_time)
        start_train_time = time.time()
        
        # save partially trained model
        if sum(training.train_times) >= partial_train_times[current_train_phase]:
            partial_train_model = NN.load_model(problem_type, model_type, train_type)
            partial_train_model.save_model(problem_type, model_type, partial_train_type) 
            current_train_phase += 1
            partial_train_type = train_type + 'PartialTrain' + str(partial_train_times[current_train_phase])
        
        # stop iterations
        if stop or training.current_epoch >= training.max_epoch or sum(training.train_times) >= training.max_time:
            training.stop_epochs.append(training.current_epoch)
            break
    
    if training.current_epoch >= training.max_epoch:
        print('Training terminated: maximum number of epochs is exceeded')
        break
        
    if sum(training.train_times) >= training.max_time:
        print('Training terminated: maximum time limit is exceeded')
        break
    
    # compute adaptive subset size for approximation of convergence criterion
    training.select_params['subset_size'] = int(100 * np.log(num_train_data/100 + 1))
    
    # select data set size
    new_num_train_data = training.select_dataset_size(train_data, model)
    training.generation_ratios.append(new_num_train_data/num_train_data)
    
    if new_num_train_data == num_train_data:
        print('Training terminated: convergence criterion is satisfied')
        break

    # generate data adaptively
    print('------------------------------------\n Adaptive Data Generation\n------------------------------------')
    # reset Adam
    #training.optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=0.01)
    while new_num_train_data > num_train_data and (sum(training.train_times) + time.time() - start_train_time) < training.max_time:
        # sample and select initial conditions with largest gradient norm
        X0_candidates = data_generation.sample_X0(problem, num_samples=10)
        X0_sample = data_generation.select_X0(problem, model, X0_candidates, num_top=1)
        
        # solve BVP with NN warm start
        solver_config = {'max_nodes':5000, 'tol':1e-5, 'replace_sample':False}
        t_data, X_aug_data, idx_samples, _ = BVP.solve_BVP(problem, X0_sample, initialization='NN_warm_start', 
                                                           init_config={'model':model}, solver_config=solver_config)
        # track number of generated data
        num_train_data += len(t_data)
        print(f'data generated: {num_train_data} / {new_num_train_data} \n')
        
        # add new data to saved data
        data_generation.update_data(t_data, X_aug_data, idx_samples, problem_type, 'train')
    
    if (sum(training.train_times) + time.time() - start_train_time) >= max_time:
        print('Training terminated: maximum time limit is exceeded')
        break

end_train_time = time.time()
training.train_times.append(end_train_time - start_train_time)
        
# save training instance
training.save_training(problem_type, model_type, train_type)
# Out:
# ------------------------------------
#  Epoch 1
# ------------------------------------
# total loss: 4.579531, value loss: 0.115302, grad loss: 0.044642 [    0/ 1261]
# total loss: 4.089809, value loss: 0.068979, grad loss: 0.040208 [ 1000/ 1261]
#
# training errors:
# value RMAE: 7.613936, grad RML1: 3.417446, ctrl RMAE: 9.904089
# validation errors:
# value RMAE: 3.914830, grad RML1: 3.250682, ctrl RMAE: 6.037319
#
# generalization loss: 0.000000
#
# ------------------------------------
#  Epoch 2
# ------------------------------------
# total loss: 4.598133, value loss: 0.110500, grad loss: 0.044876 [    0/ 1261]
# total loss: 4.255143, value loss: 0.067951, grad loss: 0.041872 [ 1000/ 1261]
#
# training errors:
# value RMAE: 7.667542, grad RML1: 3.333463, ctrl RMAE: 9.542969
# validation errors:
# value RMAE: 3.845290, grad RML1: 3.202658, ctrl RMAE: 5.948513
#
# generalization loss: 0.000000
#
# ------------------------------------
#  Epoch 3
# ------------------------------------
# total loss: 3.746390, value loss: 0.064551, grad loss: 0.036818 [    0/ 1261]
# total loss: 3.313405, value loss: 0.053497, grad loss: 0.032599 [ 1000/ 1261]
#
# training errors:
# value RMAE: 9.216640, grad RML1: 3.000904, ctrl RMAE: 8.669430
# validation errors:
# value RMAE: 4.381230, grad RML1: 3.070011, ctrl RMAE: 5.715241
#
# generalization loss: 0.000000
#
# ------------------------------------
#  Epoch 4
# ------------------------------------
# total loss: 2.780772, value loss: 0.059198, grad loss: 0.027216 [    0/ 1261]
# total loss: 1.709930, value loss: 0.051327, grad loss: 0.016586 [ 1000/ 1261]
#
# training errors:
# value RMAE: 3.685789, grad RML1: 2.001981, ctrl RMAE: 2.221205
# validation errors:
# value RMAE: 3.802887, grad RML1: 2.684846, ctrl RMAE: 4.677722
#
# generalization loss: 0.000000
#
# ------------------------------------
#  Epoch 5
# ------------------------------------
# total loss: 1.283957, value loss: 0.013031, grad loss: 0.012709 [    0/ 1261]
# total loss: 1.019868, value loss: 0.046306, grad loss: 0.009736 [ 1000/ 1261]
#
# training errors:
# value RMAE: 6.351218, grad RML1: 1.656529, ctrl RMAE: 3.206603
# validation errors:
# value RMAE: 5.797950, grad RML1: 2.642110, ctrl RMAE: 4.817454
#
# generalization loss: 0.029872
#
# ------------------------------------
#  Epoch 6
# ------------------------------------
# total loss: 1.017013, value loss: 0.029302, grad loss: 0.009877 [    0/ 1261]
# total loss: 0.793685, value loss: 0.020651, grad loss: 0.007730 [ 1000/ 1261]
#
# training errors:
# value RMAE: 6.606963, grad RML1: 1.452443, ctrl RMAE: 1.530211
# validation errors:
# value RMAE: 3.049753, grad RML1: 2.626827, ctrl RMAE: 4.631884
#
# generalization loss: 0.000000
# training progress:   2.289797
#
# ------------------------------------
#  Epoch 7
# ------------------------------------
# total loss: 0.799914, value loss: 0.030658, grad loss: 0.007693 [    0/ 1261]
# total loss: 0.593518, value loss: 0.012804, grad loss: 0.005807 [ 1000/ 1261]
#
# training errors:
# value RMAE: 4.189217, grad RML1: 1.261996, ctrl RMAE: 1.485568
# validation errors:
# value RMAE: 3.188397, grad RML1: 2.516198, ctrl RMAE: 4.633602
#
# generalization loss: 0.000371
# training progress:   1.303902
#
# ------------------------------------
#  Epoch 8
# ------------------------------------
# total loss: 0.660778, value loss: 0.017470, grad loss: 0.006433 [    0/ 1261]
# total loss: 0.412150, value loss: 0.022921, grad loss: 0.003892 [ 1000/ 1261]
#
# training errors:
# value RMAE: 3.507988, grad RML1: 1.148429, ctrl RMAE: 1.202427
# validation errors:
# value RMAE: 3.563488, grad RML1: 2.496467, ctrl RMAE: 4.601019
#
# generalization loss: 0.000000
# training progress:   0.604424
#
# ------------------------------------
#  Epoch 9
# ------------------------------------
# total loss: 0.522510, value loss: 0.009861, grad loss: 0.005126 [    0/ 1261]
# total loss: 0.349683, value loss: 0.017670, grad loss: 0.003320 [ 1000/ 1261]
#
# training errors:
# value RMAE: 3.674174, grad RML1: 1.042667, ctrl RMAE: 0.892492
# validation errors:
# value RMAE: 3.628897, grad RML1: 2.467204, ctrl RMAE: 4.553754
#
# generalization loss: 0.000000
# training progress:   0.863837
#
# ------------------------------------
#  Epoch 10
# ------------------------------------
# total loss: 0.395926, value loss: 0.009180, grad loss: 0.003867 [    0/ 1261]
# total loss: 0.264000, value loss: 0.014244, grad loss: 0.002498 [ 1000/ 1261]
#
# training errors:
# value RMAE: 4.457672, grad RML1: 0.969736, ctrl RMAE: 0.887708
# validation errors:
# value RMAE: 3.234554, grad RML1: 2.408905, ctrl RMAE: 4.455153
#
# generalization loss: 0.000000
# training progress:   0.351436
#
# ------------------------------------
#  Epoch 11
# ------------------------------------
# total loss: 0.342468, value loss: 0.011410, grad loss: 0.003311 [    0/ 1261]
# total loss: 0.239141, value loss: 0.023815, grad loss: 0.002153 [ 1000/ 1261]
#
# training errors:
# value RMAE: 5.818197, grad RML1: 0.926887, ctrl RMAE: 0.681064
# validation errors:
# value RMAE: 3.064790, grad RML1: 2.421588, ctrl RMAE: 4.446597
#
# generalization loss: 0.000000
# training progress:   0.512123
#
# ------------------------------------
#  Epoch 12
# ------------------------------------
# total loss: 0.289984, value loss: 0.024953, grad loss: 0.002650 [    0/ 1261]
# total loss: 0.289266, value loss: 0.017966, grad loss: 0.002713 [ 1000/ 1261]
#
# training errors:
# value RMAE: 6.816055, grad RML1: 0.862546, ctrl RMAE: 0.614987
# validation errors:
# value RMAE: 3.101676, grad RML1: 2.388817, ctrl RMAE: 4.398455
#
# generalization loss: 0.000000
# training progress:   0.391470
#
# ------------------------------------
#  Epoch 13
# ------------------------------------
# total loss: 0.257266, value loss: 0.035101, grad loss: 0.002222 [    0/ 1261]
# total loss: 0.223847, value loss: 0.020060, grad loss: 0.002038 [ 1000/ 1261]
#
# training errors:
# value RMAE: 3.353074, grad RML1: 0.824487, ctrl RMAE: 0.606661
# validation errors:
# value RMAE: 4.057998, grad RML1: 2.379880, ctrl RMAE: 4.358605
#
# generalization loss: 0.000000
# training progress:   0.214159
#
# ------------------------------------
#  Epoch 14
# ------------------------------------
# total loss: 0.194881, value loss: 0.016610, grad loss: 0.001783 [    0/ 1261]
# total loss: 0.212973, value loss: 0.011632, grad loss: 0.002013 [ 1000/ 1261]
#
# training errors:
# value RMAE: 3.857654, grad RML1: 0.782061, ctrl RMAE: 0.506863
# validation errors:
# value RMAE: 3.676152, grad RML1: 2.365015, ctrl RMAE: 4.336753
#
# generalization loss: 0.000000
# training progress:   0.301054
#
# ------------------------------------
#  Epoch 15
# ------------------------------------
# total loss: 0.190069, value loss: 0.013439, grad loss: 0.001766 [    0/ 1261]
# total loss: 0.224907, value loss: 0.015106, grad loss: 0.002098 [ 1000/ 1261]
#
# training errors:
# value RMAE: 3.365448, grad RML1: 0.738375, ctrl RMAE: 0.588038
# validation errors:
# value RMAE: 4.798416, grad RML1: 2.347566, ctrl RMAE: 4.338191
#
# generalization loss: 0.000332
# training progress:   0.182809
#
# ------------------------------------
#  Epoch 16
# ------------------------------------
# total loss: 0.210174, value loss: 0.015592, grad loss: 0.001946 [    0/ 1261]
# total loss: 0.200596, value loss: 0.031263, grad loss: 0.001693 [ 1000/ 1261]
#
# training errors:
# value RMAE: 7.132517, grad RML1: 0.735714, ctrl RMAE: 0.463953
# validation errors:
# value RMAE: 3.121952, grad RML1: 2.370831, ctrl RMAE: 4.373006
#
# generalization loss: 0.008359
# training progress:   0.198614
#
# ------------------------------------
#  Epoch 17
# ------------------------------------
# total loss: 0.206399, value loss: 0.036357, grad loss: 0.001700 [    0/ 1261]
# total loss: 0.154114, value loss: 0.010594, grad loss: 0.001435 [ 1000/ 1261]
#
# training errors:
# value RMAE: 3.417834, grad RML1: 0.677839, ctrl RMAE: 0.541293
# validation errors:
# value RMAE: 4.936553, grad RML1: 2.325316, ctrl RMAE: 4.353576
#
# generalization loss: 0.003879
# training progress:   0.166846
#
# ------------------------------------
#  Epoch 18
# ------------------------------------
# total loss: 0.159641, value loss: 0.019344, grad loss: 0.001403 [    0/ 1261]
# total loss: 0.128698, value loss: 0.023405, grad loss: 0.001053 [ 1000/ 1261]
#
# training errors:
# value RMAE: 4.697634, grad RML1: 0.646790, ctrl RMAE: 0.513435
# validation errors:
# value RMAE: 5.566658, grad RML1: 2.298943, ctrl RMAE: 4.234814
#
# generalization loss: 0.000000
# training progress:   0.126658
#
# ------------------------------------
#  Epoch 19
# ------------------------------------
# total loss: 0.128875, value loss: 0.027205, grad loss: 0.001017 [    0/ 1261]
# total loss: 0.141491, value loss: 0.029285, grad loss: 0.001122 [ 1000/ 1261]
#
# training errors:
# value RMAE: 6.662284, grad RML1: 0.633916, ctrl RMAE: 0.338666
# validation errors:
# value RMAE: 3.052186, grad RML1: 2.297681, ctrl RMAE: 4.247263
#
# generalization loss: 0.002940
# training progress:   0.444130
#
# ------------------------------------
#  Epoch 20
# ------------------------------------
# total loss: 0.149258, value loss: 0.030997, grad loss: 0.001183 [    0/ 1261]
# total loss: 0.125500, value loss: 0.017842, grad loss: 0.001077 [ 1000/ 1261]
#
# training errors:
# value RMAE: 5.246643, grad RML1: 0.617821, ctrl RMAE: 0.494904
# validation errors:
# value RMAE: 5.873318, grad RML1: 2.321662, ctrl RMAE: 4.303294
#
# generalization loss: 0.016171
# training progress:   0.389129
#
# ------------------------------------
#  Epoch 21
# ------------------------------------
# total loss: 0.150376, value loss: 0.037353, grad loss: 0.001130 [    0/ 1261]
# total loss: 0.128727, value loss: 0.023131, grad loss: 0.001056 [ 1000/ 1261]
#
# training errors:
# value RMAE: 3.627242, grad RML1: 0.589580, ctrl RMAE: 0.306814
# validation errors:
# value RMAE: 4.070549, grad RML1: 2.344400, ctrl RMAE: 4.295688
#
# generalization loss: 0.014375
# training progress:   0.430905
#
# ------------------------------------
#  Epoch 22
# ------------------------------------
# total loss: 0.125489, value loss: 0.024312, grad loss: 0.001012 [    0/ 1261]
# total loss: 0.122712, value loss: 0.023015, grad loss: 0.000997 [ 1000/ 1261]
#
# training errors:
# value RMAE: 3.410952, grad RML1: 0.563039, ctrl RMAE: 0.360074
# validation errors:
# value RMAE: 4.864851, grad RML1: 2.281574, ctrl RMAE: 4.235559
#
# generalization loss: 0.000176
# training progress:   0.312776
#
# ------------------------------------
#  Epoch 23
# ------------------------------------
# total loss: 0.118508, value loss: 0.018954, grad loss: 0.000996 [    0/ 1261]
# total loss: 0.128069, value loss: 0.033892, grad loss: 0.000942 [ 1000/ 1261]
#
# training errors:
# value RMAE: 3.282649, grad RML1: 0.561108, ctrl RMAE: 0.614808
# validation errors:
# value RMAE: 4.748201, grad RML1: 2.293604, ctrl RMAE: 4.255182
#
# generalization loss: 0.004810
# training progress:   0.378856
#
# ------------------------------------
#  Epoch 24
# ------------------------------------
# total loss: 0.108987, value loss: 0.022247, grad loss: 0.000867 [    0/ 1261]
# total loss: 0.114536, value loss: 0.032589, grad loss: 0.000819 [ 1000/ 1261]
#
# training errors:
# value RMAE: 5.238328, grad RML1: 0.520972, ctrl RMAE: 0.255978
# validation errors:
# value RMAE: 3.252530, grad RML1: 2.282934, ctrl RMAE: 4.258666
#
# generalization loss: 0.005632
# training progress:   0.588090
#
# ------------------------------------
#  Epoch 25
# ------------------------------------
# total loss: 0.095913, value loss: 0.017930, grad loss: 0.000780 [    0/ 1261]
# total loss: 0.094749, value loss: 0.017145, grad loss: 0.000776 [ 1000/ 1261]
#
# training errors:
# value RMAE: 4.272942, grad RML1: 0.505482, ctrl RMAE: 0.246419
# validation errors:
# value RMAE: 3.571642, grad RML1: 2.286024, ctrl RMAE: 4.207718
#
# generalization loss: 0.000000
# training progress:   0.448013
#
# ------------------------------------
#  Epoch 26
# ------------------------------------
# total loss: 0.086202, value loss: 0.019098, grad loss: 0.000671 [    0/ 1261]
# total loss: 0.099530, value loss: 0.023372, grad loss: 0.000762 [ 1000/ 1261]
#
# training errors:
# value RMAE: 3.869337, grad RML1: 0.507627, ctrl RMAE: 0.368806
# validation errors:
# value RMAE: 5.171748, grad RML1: 2.263471, ctrl RMAE: 4.194819
#
# generalization loss: 0.000000
# training progress:   0.498327
#
# ------------------------------------
#  Epoch 27
# ------------------------------------
# total loss: 0.108201, value loss: 0.027842, grad loss: 0.000804 [    0/ 1261]
# total loss: 0.092017, value loss: 0.026534, grad loss: 0.000655 [ 1000/ 1261]
#
# training errors:
# value RMAE: 5.091364, grad RML1: 0.476606, ctrl RMAE: 0.272795
# validation errors:
# value RMAE: 3.214942, grad RML1: 2.279821, ctrl RMAE: 4.232161
#
# generalization loss: 0.008902
# training progress:   0.427489
#
# ------------------------------------
#  Epoch 28
# ------------------------------------
# total loss: 0.078498, value loss: 0.017435, grad loss: 0.000611 [    0/ 1261]
# total loss: 0.075827, value loss: 0.022575, grad loss: 0.000533 [ 1000/ 1261]
#
# training errors:
# value RMAE: 5.769731, grad RML1: 0.470094, ctrl RMAE: 0.217274
# validation errors:
# value RMAE: 3.104357, grad RML1: 2.322899, ctrl RMAE: 4.292893
#
# generalization loss: 0.023380
# training progress:   0.253046
#
# ------------------------------------
#  Epoch 29
# ------------------------------------
# total loss: 0.082070, value loss: 0.021615, grad loss: 0.000605 [    0/ 1261]
# total loss: 0.085369, value loss: 0.013622, grad loss: 0.000717 [ 1000/ 1261]
#
# training errors:
# value RMAE: 5.179812, grad RML1: 0.458177, ctrl RMAE: 0.233591
# validation errors:
# value RMAE: 3.206002, grad RML1: 2.287850, ctrl RMAE: 4.257599
#
# generalization loss: 0.014966
# training progress:   0.232439
#
# ------------------------------------
#  Epoch 30
# ------------------------------------
# total loss: 0.091932, value loss: 0.027451, grad loss: 0.000645 [    0/ 1261]
# total loss: 0.090533, value loss: 0.026876, grad loss: 0.000637 [ 1000/ 1261]
#
# training errors:
# value RMAE: 3.833313, grad RML1: 0.447561, ctrl RMAE: 0.281286
# validation errors:
# value RMAE: 3.754616, grad RML1: 2.274393, ctrl RMAE: 4.264450
#
# generalization loss: 0.016599
# training progress:   0.264534
#
# ------------------------------------
#  Epoch 31
# ------------------------------------
# total loss: 0.069410, value loss: 0.017448, grad loss: 0.000520 [    0/ 1261]
# total loss: 0.079469, value loss: 0.020374, grad loss: 0.000591 [ 1000/ 1261]
#
# training errors:
# value RMAE: 7.998864, grad RML1: 0.472718, ctrl RMAE: 0.479827
# validation errors:
# value RMAE: 7.129260, grad RML1: 2.282062, ctrl RMAE: 4.227241
#
# generalization loss: 0.007729
# training progress:   0.366728
#
# ------------------------------------
#  Epoch 32
# ------------------------------------
# total loss: 0.112707, value loss: 0.046498, grad loss: 0.000662 [    0/ 1261]
# total loss: 0.065170, value loss: 0.017484, grad loss: 0.000477 [ 1000/ 1261]
#
# training errors:
# value RMAE: 3.645770, grad RML1: 0.414522, ctrl RMAE: 0.237669
# validation errors:
# value RMAE: 3.778572, grad RML1: 2.260892, ctrl RMAE: 4.211007
#
# generalization loss: 0.003859
# training progress:   0.334395
#
# ------------------------------------
#  Epoch 33
# ------------------------------------
# total loss: 0.059673, value loss: 0.010822, grad loss: 0.000489 [    0/ 1261]
# total loss: 0.075461, value loss: 0.030047, grad loss: 0.000454 [ 1000/ 1261]
#
# training errors:
# value RMAE: 6.745535, grad RML1: 0.438332, ctrl RMAE: 0.173867
# validation errors:
# value RMAE: 2.977180, grad RML1: 2.292839, ctrl RMAE: 4.233623
#
# generalization loss: 0.009250
# training progress:   0.617601
#
# ------------------------------------
#  Epoch 34
# ------------------------------------
# total loss: 0.080488, value loss: 0.029958, grad loss: 0.000505 [    0/ 1261]
# total loss: 0.088754, value loss: 0.038041, grad loss: 0.000507 [ 1000/ 1261]
#
# training errors:
# value RMAE: 4.296899, grad RML1: 0.425721, ctrl RMAE: 0.381387
# validation errors:
# value RMAE: 5.345775, grad RML1: 2.267499, ctrl RMAE: 4.214295
#
# generalization loss: 0.004643
# training progress:   0.787612
#
# ------------------------------------
#  Epoch 35
# ------------------------------------
# total loss: 0.065737, value loss: 0.016243, grad loss: 0.000495 [    0/ 1261]
# total loss: 0.073512, value loss: 0.025709, grad loss: 0.000478 [ 1000/ 1261]
#
# training errors:
# value RMAE: 4.579857, grad RML1: 0.397972, ctrl RMAE: 0.167134
# validation errors:
# value RMAE: 3.226376, grad RML1: 2.251428, ctrl RMAE: 4.161509
#
# generalization loss: 0.000000
# training progress:   0.723027
#
# ------------------------------------
#  Epoch 36
# ------------------------------------
# total loss: 0.069583, value loss: 0.023026, grad loss: 0.000466 [    0/ 1261]
# total loss: 0.059890, value loss: 0.014594, grad loss: 0.000453 [ 1000/ 1261]
#
# training errors:
# value RMAE: 3.006005, grad RML1: 0.391624, ctrl RMAE: 0.269350
# validation errors:
# value RMAE: 4.594453, grad RML1: 2.260265, ctrl RMAE: 4.189417
#
# generalization loss: 0.006706
# training progress:   0.471162
#
# ------------------------------------
#  Epoch 37
# ------------------------------------
# total loss: 0.058858, value loss: 0.017973, grad loss: 0.000409 [    0/ 1261]
# total loss: 0.090880, value loss: 0.043320, grad loss: 0.000476 [ 1000/ 1261]
# training errors:
# value RMAE: 8.511093, grad RML1: 0.439848, ctrl RMAE: 0.214703
# validation errors:
# value RMAE: 3.135347, grad RML1: 2.278507, ctrl RMAE: 4.196950
#
# generalization loss: 0.008517
# training progress:   0.443680
#
# ------------------------------------
#  Epoch 38
# ------------------------------------
# total loss: 0.098954, value loss: 0.047468, grad loss: 0.000515 [    0/ 1261]
# total loss: 0.058446, value loss: 0.016312, grad loss: 0.000421 [ 1000/ 1261]
#
# training errors:
# value RMAE: 3.212065, grad RML1: 0.402554, ctrl RMAE: 0.291880
# validation errors:
# value RMAE: 4.793502, grad RML1: 2.260537, ctrl RMAE: 4.166567
#
# generalization loss: 0.001215
# training progress:   0.584899
#
# ------------------------------------
#  Epoch 39
# ------------------------------------
# total loss: 0.066006, value loss: 0.019440, grad loss: 0.000466 [    0/ 1261]
# total loss: 0.056628, value loss: 0.015758, grad loss: 0.000409 [ 1000/ 1261]
#
# training errors:
# value RMAE: 3.707712, grad RML1: 0.377788, ctrl RMAE: 0.160508
# validation errors:
# value RMAE: 3.692480, grad RML1: 2.261163, ctrl RMAE: 4.218091
#
# generalization loss: 0.013597
# training progress:   0.375102
#
# ------------------------------------
#  Epoch 40
# ------------------------------------
# total loss: 0.059319, value loss: 0.018807, grad loss: 0.000405 [    0/ 1261]
# total loss: 0.055554, value loss: 0.019787, grad loss: 0.000358 [ 1000/ 1261]
#
# training errors:
# value RMAE: 3.108187, grad RML1: 0.368224, ctrl RMAE: 0.236810
# validation errors:
# value RMAE: 4.046851, grad RML1: 2.254249, ctrl RMAE: 4.214620
#
# generalization loss: 0.012763
# training progress:   0.461921
#
# ------------------------------------
#  Epoch 41
# ------------------------------------
# total loss: 0.056751, value loss: 0.019397, grad loss: 0.000374 [    0/ 1261]
# total loss: 0.053387, value loss: 0.016936, grad loss: 0.000365 [ 1000/ 1261]
#
# training errors:
# value RMAE: 3.904963, grad RML1: 0.357507, ctrl RMAE: 0.215187
# validation errors:
# value RMAE: 3.403062, grad RML1: 2.265302, ctrl RMAE: 4.217249
#
# generalization loss: 0.013394
# training progress:   0.394431
#
# ------------------------------------
#  Epoch 42
# ------------------------------------
# total loss: 0.065365, value loss: 0.026771, grad loss: 0.000386 [    0/ 1261]
# total loss: 0.055581, value loss: 0.017554, grad loss: 0.000380 [ 1000/ 1261]
#
# training errors:
# value RMAE: 2.974726, grad RML1: 0.372388, ctrl RMAE: 0.304699
# validation errors:
# value RMAE: 4.710187, grad RML1: 2.246030, ctrl RMAE: 4.193069
#
# generalization loss: 0.007584
# training progress:   0.506569
#
# ------------------------------------
#  Epoch 43
# ------------------------------------
# total loss: 0.056924, value loss: 0.019798, grad loss: 0.000371 [    0/ 1261]
# total loss: 0.053827, value loss: 0.016351, grad loss: 0.000375 [ 1000/ 1261]
#
# training errors:
# value RMAE: 3.729196, grad RML1: 0.362069, ctrl RMAE: 0.184792
# validation errors:
# value RMAE: 3.500460, grad RML1: 2.245751, ctrl RMAE: 4.191037
#
# generalization loss: 0.007096
# training progress:   0.373133
#
# ------------------------------------
#  Epoch 44
# ------------------------------------
# total loss: 0.050790, value loss: 0.013646, grad loss: 0.000371 [    0/ 1261]
# total loss: 0.048728, value loss: 0.013848, grad loss: 0.000349 [ 1000/ 1261]
#
# training errors:
# value RMAE: 4.872849, grad RML1: 0.354733, ctrl RMAE: 0.143028
# validation errors:
# value RMAE: 3.105504, grad RML1: 2.262774, ctrl RMAE: 4.208069
#
# generalization loss: 0.011188
# training progress:   0.516509
#
# ------------------------------------
#  Epoch 45
# ------------------------------------
# total loss: 0.055397, value loss: 0.017151, grad loss: 0.000382 [    0/ 1261]
# total loss: 0.052517, value loss: 0.016280, grad loss: 0.000362 [ 1000/ 1261]
#
# training errors:
# value RMAE: 3.114650, grad RML1: 0.372929, ctrl RMAE: 0.260941
# validation errors:
# value RMAE: 4.778175, grad RML1: 2.262583, ctrl RMAE: 4.215477
#
# generalization loss: 0.012968
# training progress:   0.550251
#
# ------------------------------------
#  Epoch 46
# ------------------------------------
# total loss: 0.061994, value loss: 0.019838, grad loss: 0.000422 [    0/ 1261]
# total loss: 0.054068, value loss: 0.016958, grad loss: 0.000371 [ 1000/ 1261]
#
# training errors:
# value RMAE: 3.687706, grad RML1: 0.346232, ctrl RMAE: 0.159615
# validation errors:
# value RMAE: 3.623069, grad RML1: 2.268956, ctrl RMAE: 4.251176
#
# generalization loss: 0.021547
# training progress:   0.472543
#
# ------------------------------------
#  Epoch 47
# ------------------------------------
# total loss: 0.057305, value loss: 0.021213, grad loss: 0.000361 [    0/ 1261]
# total loss: 0.045635, value loss: 0.010905, grad loss: 0.000347 [ 1000/ 1261]
#
# training errors:
# value RMAE: 4.154936, grad RML1: 0.345191, ctrl RMAE: 0.177144
# validation errors:
# value RMAE: 3.244326, grad RML1: 2.259198, ctrl RMAE: 4.208342
#
# generalization loss: 0.011254
# training progress:   0.294180
#
# ------------------------------------
#  Epoch 48
# ------------------------------------
# total loss: 0.053548, value loss: 0.017487, grad loss: 0.000361 [    0/ 1261]
# total loss: 0.054218, value loss: 0.015498, grad loss: 0.000387 [ 1000/ 1261]
#
# training errors:
# value RMAE: 4.591088, grad RML1: 0.338366, ctrl RMAE: 0.156709
# validation errors:
# value RMAE: 3.142686, grad RML1: 2.240924, ctrl RMAE: 4.178150
#
# generalization loss: 0.003999
# training progress:   0.254912
#
# ------------------------------------
#  Epoch 49
# ------------------------------------
# total loss: 0.051086, value loss: 0.020431, grad loss: 0.000307 [    0/ 1261]
# total loss: 0.068380, value loss: 0.031027, grad loss: 0.000374 [ 1000/ 1261]
#
# training errors:
# value RMAE: 5.859620, grad RML1: 0.356288, ctrl RMAE: 0.161065
# validation errors:
# value RMAE: 2.914579, grad RML1: 2.263875, ctrl RMAE: 4.198943
#
# generalization loss: 0.008995
# training progress:   0.168372
#
# ------------------------------------
#  Epoch 50
# ------------------------------------
# total loss: 0.064473, value loss: 0.023859, grad loss: 0.000406 [    0/ 1261]
# total loss: 0.092700, value loss: 0.052186, grad loss: 0.000405 [ 1000/ 1261]
#
# training errors:
# value RMAE: 4.313029, grad RML1: 0.333686, ctrl RMAE: 0.185779
# validation errors:
# value RMAE: 3.125508, grad RML1: 2.259057, ctrl RMAE: 4.216193
#
# generalization loss: 0.013141
# training progress:   0.072447
#
# ------------------------------------
#  Adaptive Data Generation
# ------------------------------------
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 400 data points (from 210 initially guessed points)
# solution time:       4.517448 of which 2.642931 solving BVP
# solution time per data point: 0.011294
#
# data generated: 1661 / 1576
#
# ------------------------------------
#  Epoch 51
# ------------------------------------
# total loss: 0.407020, value loss: 0.023126, grad loss: 0.003839 [    0/ 1661]
# total loss: 0.390585, value loss: 0.018679, grad loss: 0.003719 [ 1000/ 1661]
#
# training errors:
# value RMAE: 6.411601, grad RML1: 0.751976, ctrl RMAE: 0.767291
# validation errors:
# value RMAE: 2.880612, grad RML1: 2.266770, ctrl RMAE: 4.076747
#
# generalization loss: 0.000000
# training progress:   0.847992
#
# ------------------------------------
#  Epoch 52
# ------------------------------------
# total loss: 0.149396, value loss: 0.025059, grad loss: 0.001243 [    0/ 1661]
# total loss: 0.147203, value loss: 0.019292, grad loss: 0.001279 [ 1000/ 1661]
#
# training errors:
# value RMAE: 4.251622, grad RML1: 0.638149, ctrl RMAE: 0.674651
# validation errors:
# value RMAE: 4.343354, grad RML1: 2.181406, ctrl RMAE: 4.020975
#
# generalization loss: 0.000000
# training progress:   1.482934
#
# ------------------------------------
#  Epoch 53
# ------------------------------------
# total loss: 0.148503, value loss: 0.016726, grad loss: 0.001318 [    0/ 1661]
# total loss: 0.222924, value loss: 0.024466, grad loss: 0.001985 [ 1000/ 1661]
#
# training errors:
# value RMAE: 8.503044, grad RML1: 0.573445, ctrl RMAE: 0.393588
# validation errors:
# value RMAE: 2.916767, grad RML1: 2.187239, ctrl RMAE: 4.002150
#
# generalization loss: 0.000000
# training progress:   1.709934
#
# ------------------------------------
#  Epoch 54
# ------------------------------------
# total loss: 0.161413, value loss: 0.035658, grad loss: 0.001258 [    0/ 1661]
# total loss: 0.144102, value loss: 0.021869, grad loss: 0.001222 [ 1000/ 1661]
#
# training errors:
# value RMAE: 4.985183, grad RML1: 0.510644, ctrl RMAE: 0.382499
# validation errors:
# value RMAE: 3.079033, grad RML1: 2.160636, ctrl RMAE: 3.950336
#
# generalization loss: 0.000000
# training progress:   1.587809
#
# ------------------------------------
#  Epoch 55
# ------------------------------------
# total loss: 0.130494, value loss: 0.018264, grad loss: 0.001122 [    0/ 1661]
# total loss: 0.087899, value loss: 0.023761, grad loss: 0.000641 [ 1000/ 1661]
#
# training errors:
# value RMAE: 5.462069, grad RML1: 0.453863, ctrl RMAE: 0.265222
# validation errors:
# value RMAE: 2.869580, grad RML1: 2.133209, ctrl RMAE: 3.876803
#
# generalization loss: 0.000000
# training progress:   0.872581
#
# ------------------------------------
#  Epoch 56
# ------------------------------------
# total loss: 0.110868, value loss: 0.016380, grad loss: 0.000945 [    0/ 1661]
# total loss: 0.108384, value loss: 0.019493, grad loss: 0.000889 [ 1000/ 1661]
#
# training errors:
# value RMAE: 3.783766, grad RML1: 0.427814, ctrl RMAE: 0.364228
# validation errors:
# value RMAE: 4.135607, grad RML1: 2.126829, ctrl RMAE: 3.903474
#
# generalization loss: 0.006880
# training progress:   0.568638
#
# ------------------------------------
#  Epoch 57
# ------------------------------------
# total loss: 0.077781, value loss: 0.016289, grad loss: 0.000615 [    0/ 1661]
# total loss: 0.080543, value loss: 0.022213, grad loss: 0.000583 [ 1000/ 1661]
#
# training errors:
# value RMAE: 5.562148, grad RML1: 0.405619, ctrl RMAE: 0.247388
# validation errors:
# value RMAE: 2.775388, grad RML1: 2.121953, ctrl RMAE: 3.869201
#
# generalization loss: 0.000000
# training progress:   0.336304
#
# ------------------------------------
#  Epoch 58
# ------------------------------------
# total loss: 0.063419, value loss: 0.020012, grad loss: 0.000434 [    0/ 1661]
# total loss: 0.074618, value loss: 0.015951, grad loss: 0.000587 [ 1000/ 1661]
#
# training errors:
# value RMAE: 4.763545, grad RML1: 0.391349, ctrl RMAE: 0.231680
# validation errors:
# value RMAE: 3.031247, grad RML1: 2.128193, ctrl RMAE: 3.925629
#
# generalization loss: 0.014584
# training progress:   0.287135
#
# ------------------------------------
#  Epoch 59
# ------------------------------------
# total loss: 0.067269, value loss: 0.014861, grad loss: 0.000524 [    0/ 1661]
# total loss: 0.058729, value loss: 0.012496, grad loss: 0.000462 [ 1000/ 1661]
#
# training errors:
# value RMAE: 4.675190, grad RML1: 0.387640, ctrl RMAE: 0.226239
# validation errors:
# value RMAE: 2.977653, grad RML1: 2.114884, ctrl RMAE: 3.870045
#
# generalization loss: 0.000218
# training progress:   0.179952
#
# ------------------------------------
#  Epoch 60
# ------------------------------------
# total loss: 0.052032, value loss: 0.015475, grad loss: 0.000366 [    0/ 1661]
# total loss: 0.089426, value loss: 0.036008, grad loss: 0.000534 [ 1000/ 1661]
#
# training errors:
# value RMAE: 6.171990, grad RML1: 0.377163, ctrl RMAE: 0.192633
# validation errors:
# value RMAE: 2.710289, grad RML1: 2.117872, ctrl RMAE: 3.874468
#
# generalization loss: 0.001361
# training progress:   0.310438
#
# ------------------------------------
#  Epoch 61
# ------------------------------------
# total loss: 0.056034, value loss: 0.020566, grad loss: 0.000355 [    0/ 1661]
# total loss: 0.058450, value loss: 0.018284, grad loss: 0.000402 [ 1000/ 1661]
#
# training errors:
# value RMAE: 4.891625, grad RML1: 0.382862, ctrl RMAE: 0.196171
# validation errors:
# value RMAE: 2.853343, grad RML1: 2.134014, ctrl RMAE: 3.857239
#
# generalization loss: 0.000000
# training progress:   0.135954
#
# ------------------------------------
#  Epoch 62
# ------------------------------------
# total loss: 0.054895, value loss: 0.019679, grad loss: 0.000352 [    0/ 1661]
# total loss: 0.054897, value loss: 0.018673, grad loss: 0.000362 [ 1000/ 1661]
#
# training errors:
# value RMAE: 7.728737, grad RML1: 0.375270, ctrl RMAE: 0.239630
# validation errors:
# value RMAE: 2.686099, grad RML1: 2.102037, ctrl RMAE: 3.776114
#
# generalization loss: 0.000000
# training progress:   0.127899
#
# ------------------------------------
#  Epoch 63
# ------------------------------------
# total loss: 0.062650, value loss: 0.030575, grad loss: 0.000321 [    0/ 1661]
# total loss: 0.058435, value loss: 0.012439, grad loss: 0.000460 [ 1000/ 1661]
#
# training errors:
# value RMAE: 9.959973, grad RML1: 0.387893, ctrl RMAE: 0.207998
# validation errors:
# value RMAE: 3.140010, grad RML1: 2.116923, ctrl RMAE: 3.786714
#
# generalization loss: 0.002807
# training progress:   0.103312
#
# ------------------------------------
#  Epoch 64
# ------------------------------------
# total loss: 0.090731, value loss: 0.047919, grad loss: 0.000428 [    0/ 1661]
# total loss: 0.079327, value loss: 0.039900, grad loss: 0.000394 [ 1000/ 1661]
#
# training errors:
# value RMAE: 7.146952, grad RML1: 0.387945, ctrl RMAE: 0.451332
# validation errors:
# value RMAE: 5.655439, grad RML1: 2.099578, ctrl RMAE: 3.900045
#
# generalization loss: 0.032820
# training progress:   0.337013
#
# ------------------------------------
#  Epoch 65
# ------------------------------------
# total loss: 0.059731, value loss: 0.025019, grad loss: 0.000347 [    0/ 1661]
# total loss: 0.051712, value loss: 0.012400, grad loss: 0.000393 [ 1000/ 1661]
#
# training errors:
# value RMAE: 3.856290, grad RML1: 0.352433, ctrl RMAE: 0.262025
# validation errors:
# value RMAE: 3.077130, grad RML1: 2.100324, ctrl RMAE: 3.826573
#
# generalization loss: 0.013363
# training progress:   0.383645
#
# ------------------------------------
#  Epoch 66
# ------------------------------------
# total loss: 0.047910, value loss: 0.012684, grad loss: 0.000352 [    0/ 1661]
# total loss: 0.042245, value loss: 0.012729, grad loss: 0.000295 [ 1000/ 1661]
#
# training errors:
# value RMAE: 6.681920, grad RML1: 0.362589, ctrl RMAE: 0.399810
# validation errors:
# value RMAE: 5.471357, grad RML1: 2.079526, ctrl RMAE: 3.822401
#
# generalization loss: 0.012258
# training progress:   0.500777
#
# ------------------------------------
#  Epoch 67
# ------------------------------------
# total loss: 0.055988, value loss: 0.021956, grad loss: 0.000340 [    0/ 1661]
# total loss: 0.052084, value loss: 0.019218, grad loss: 0.000329 [ 1000/ 1661]
#
# training errors:
# value RMAE: 3.936121, grad RML1: 0.335482, ctrl RMAE: 0.208495
# validation errors:
# value RMAE: 3.054828, grad RML1: 2.119314, ctrl RMAE: 3.856270
#
# generalization loss: 0.021227
# training progress:   0.470840
#
# ------------------------------------
#  Epoch 68
# ------------------------------------
# total loss: 0.045554, value loss: 0.011536, grad loss: 0.000340 [    0/ 1661]
# total loss: 0.043818, value loss: 0.011222, grad loss: 0.000326 [ 1000/ 1661]
#
# training errors:
# value RMAE: 9.405114, grad RML1: 0.369747, ctrl RMAE: 0.201989
# validation errors:
# value RMAE: 3.039984, grad RML1: 2.104653, ctrl RMAE: 3.791312
#
# generalization loss: 0.004025
# training progress:   0.508646
#
# ------------------------------------
#  Epoch 69
# ------------------------------------
# total loss: 0.074134, value loss: 0.042085, grad loss: 0.000320 [    0/ 1661]
# total loss: 0.040131, value loss: 0.012754, grad loss: 0.000274 [ 1000/ 1661]
#
# training errors:
# value RMAE: 4.440019, grad RML1: 0.329117, ctrl RMAE: 0.182084
# validation errors:
# value RMAE: 2.783090, grad RML1: 2.085193, ctrl RMAE: 3.766642
#
# generalization loss: 0.000000
# training progress:   0.377827
#
# ------------------------------------
#  Epoch 70
# ------------------------------------
# total loss: 0.040319, value loss: 0.015125, grad loss: 0.000252 [    0/ 1661]
# total loss: 0.036310, value loss: 0.008072, grad loss: 0.000282 [ 1000/ 1661]
#
# training errors:
# value RMAE: 5.782609, grad RML1: 0.320608, ctrl RMAE: 0.163454
# validation errors:
# value RMAE: 2.536689, grad RML1: 2.060581, ctrl RMAE: 3.694216
#
# generalization loss: 0.000000
# training progress:   0.414259
#
# ------------------------------------
#  Epoch 71
# ------------------------------------
# total loss: 0.050198, value loss: 0.018449, grad loss: 0.000317 [    0/ 1661]
# total loss: 0.042999, value loss: 0.013448, grad loss: 0.000296 [ 1000/ 1661]
#
# training errors:
# value RMAE: 3.294873, grad RML1: 0.328425, ctrl RMAE: 0.203762
# validation errors:
# value RMAE: 3.262922, grad RML1: 2.087716, ctrl RMAE: 3.780573
#
# generalization loss: 0.023376
# training progress:   0.174377
#
# ------------------------------------
#  Adaptive Data Generation
# ------------------------------------
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 406 data points (from 211 initially guessed points)
# solution time:       4.295417 of which 2.458518 solving BVP
# solution time per data point: 0.010580
#
# data generated: 2067 / 2076
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 400 data points (from 210 initially guessed points)
# solution time:       4.288432 of which 2.480501 solving BVP
# solution time per data point: 0.010721
#
# data generated: 2467 / 2076
#
# ------------------------------------
#  Epoch 72
# ------------------------------------
# total loss: 0.627776, value loss: 0.029936, grad loss: 0.005978 [    0/ 2467]
# total loss: 0.330701, value loss: 0.024407, grad loss: 0.003063 [ 1000/ 2467]
# total loss: 0.527446, value loss: 0.028821, grad loss: 0.004986 [ 2000/ 2467]
#
# training errors:
# value RMAE: 5.514200, grad RML1: 0.657755, ctrl RMAE: 0.860909
# validation errors:
# value RMAE: 2.477445, grad RML1: 1.941893, ctrl RMAE: 3.462813
#
# generalization loss: 0.000000
# training progress:   0.972661
#
# ------------------------------------
#  Epoch 73
# ------------------------------------
# total loss: 0.231666, value loss: 0.021396, grad loss: 0.002103 [    0/ 2467]
# total loss: 0.371604, value loss: 0.019543, grad loss: 0.003521 [ 1000/ 2467]
# total loss: 0.115968, value loss: 0.020577, grad loss: 0.000954 [ 2000/ 2467]
#
# training errors:
# value RMAE: 4.993305, grad RML1: 0.581562, ctrl RMAE: 0.431396
# validation errors:
# value RMAE: 2.466896, grad RML1: 2.022179, ctrl RMAE: 3.509350
#
# generalization loss: 0.013439
# training progress:   1.253360
#
# ------------------------------------
#  Epoch 74
# ------------------------------------
# total loss: 0.211872, value loss: 0.019536, grad loss: 0.001923 [    0/ 2467]
# total loss: 0.126856, value loss: 0.021383, grad loss: 0.001055 [ 1000/ 2467]
# total loss: 0.120265, value loss: 0.012325, grad loss: 0.001079 [ 2000/ 2467]
#
# training errors:
# value RMAE: 5.601714, grad RML1: 0.517674, ctrl RMAE: 0.338473
# validation errors:
# value RMAE: 2.501396, grad RML1: 1.970346, ctrl RMAE: 3.423354
#
# generalization loss: 0.000000
# training progress:   1.444715
#
# ------------------------------------
#  Epoch 75
# ------------------------------------
# total loss: 0.129006, value loss: 0.021334, grad loss: 0.001077 [    0/ 2467]
# total loss: 0.129479, value loss: 0.019107, grad loss: 0.001104 [ 1000/ 2467]
# total loss: 0.085868, value loss: 0.023532, grad loss: 0.000623 [ 2000/ 2467]
#
# training errors:
# value RMAE: 7.036127, grad RML1: 0.467990, ctrl RMAE: 0.276426
# validation errors:
# value RMAE: 2.939195, grad RML1: 1.985930, ctrl RMAE: 3.457690
#
# generalization loss: 0.010030
# training progress:   1.071995
#
# ------------------------------------
#  Epoch 76
# ------------------------------------
# total loss: 0.133356, value loss: 0.031915, grad loss: 0.001014 [    0/ 2467]
# total loss: 0.100995, value loss: 0.042500, grad loss: 0.000585 [ 1000/ 2467]
# total loss: 0.124849, value loss: 0.021362, grad loss: 0.001035 [ 2000/ 2467]
#
# training errors:
# value RMAE: 3.645147, grad RML1: 0.436484, ctrl RMAE: 0.282773
# validation errors:
# value RMAE: 2.558898, grad RML1: 1.936326, ctrl RMAE: 3.439037
#
# generalization loss: 0.004581
# training progress:   0.584496
#
# ------------------------------------
#  Epoch 77
# ------------------------------------
# total loss: 0.073242, value loss: 0.011452, grad loss: 0.000618 [    0/ 2467]
# total loss: 0.088167, value loss: 0.014647, grad loss: 0.000735 [ 1000/ 2467]
# total loss: 0.075058, value loss: 0.024800, grad loss: 0.000503 [ 2000/ 2467]
#
# training errors:
# value RMAE: 5.775795, grad RML1: 0.412625, ctrl RMAE: 0.220125
# validation errors:
# value RMAE: 2.525806, grad RML1: 1.947040, ctrl RMAE: 3.382405
#
# generalization loss: 0.000000
# training progress:   0.407559
#
# ------------------------------------
#  Epoch 78
# ------------------------------------
# total loss: 0.090055, value loss: 0.023323, grad loss: 0.000667 [    0/ 2467]
# total loss: 0.072858, value loss: 0.011904, grad loss: 0.000610 [ 1000/ 2467]
# total loss: 0.055358, value loss: 0.013777, grad loss: 0.000416 [ 2000/ 2467]
#
# training errors:
# value RMAE: 2.787213, grad RML1: 0.395750, ctrl RMAE: 0.285033
# validation errors:
# value RMAE: 3.225644, grad RML1: 1.945771, ctrl RMAE: 3.452343
#
# generalization loss: 0.020677
# training progress:   0.274577
#
# ------------------------------------
#  Epoch 79
# ------------------------------------
# total loss: 0.059671, value loss: 0.013352, grad loss: 0.000463 [    0/ 2467]
# total loss: 0.090596, value loss: 0.038729, grad loss: 0.000519 [ 1000/ 2467]
# total loss: 0.059396, value loss: 0.012787, grad loss: 0.000466 [ 2000/ 2467]
#
# training errors:
# value RMAE: 3.927477, grad RML1: 0.367340, ctrl RMAE: 0.265611
# validation errors:
# value RMAE: 4.094190, grad RML1: 1.928729, ctrl RMAE: 3.415164
#
# generalization loss: 0.009685
# training progress:   0.208376
#
# ------------------------------------
#  Epoch 80
# ------------------------------------
# total loss: 0.054841, value loss: 0.018171, grad loss: 0.000367 [    0/ 2467]
# total loss: 0.062604, value loss: 0.022783, grad loss: 0.000398 [ 1000/ 2467]
# total loss: 0.067221, value loss: 0.019876, grad loss: 0.000473 [ 2000/ 2467]
#
# training errors:
# value RMAE: 3.800209, grad RML1: 0.348934, ctrl RMAE: 0.190243
# validation errors:
# value RMAE: 2.363830, grad RML1: 1.895418, ctrl RMAE: 3.353270
#
# generalization loss: 0.000000
# training progress:   0.307574
#
# ------------------------------------
#  Epoch 81
# ------------------------------------
# total loss: 0.047962, value loss: 0.012073, grad loss: 0.000359 [    0/ 2467]
# total loss: 0.053452, value loss: 0.011850, grad loss: 0.000416 [ 1000/ 2467]
# total loss: 0.051014, value loss: 0.009899, grad loss: 0.000411 [ 2000/ 2467]
#
# training errors:
# value RMAE: 6.776693, grad RML1: 0.376448, ctrl RMAE: 0.219720
# validation errors:
# value RMAE: 2.840976, grad RML1: 1.918543, ctrl RMAE: 3.309171
#
# generalization loss: 0.000000
# training progress:   0.241288
#
# ------------------------------------
#  Epoch 82
# ------------------------------------
# total loss: 0.065928, value loss: 0.028643, grad loss: 0.000373 [    0/ 2467]
# total loss: 0.075806, value loss: 0.031152, grad loss: 0.000447 [ 1000/ 2467]
# total loss: 0.067488, value loss: 0.028684, grad loss: 0.000388 [ 2000/ 2467]
#
# training errors:
# value RMAE: 7.738389, grad RML1: 0.373596, ctrl RMAE: 0.177449
# validation errors:
# value RMAE: 3.269605, grad RML1: 1.943563, ctrl RMAE: 3.349185
#
# generalization loss: 0.012092
# training progress:   0.282686
#
# ------------------------------------
#  Epoch 83
# ------------------------------------
# total loss: 0.080126, value loss: 0.039829, grad loss: 0.000403 [    0/ 2467]
# total loss: 0.049792, value loss: 0.016890, grad loss: 0.000329 [ 1000/ 2467]
# total loss: 0.044533, value loss: 0.010099, grad loss: 0.000344 [ 2000/ 2467]
#
# training errors:
# value RMAE: 3.043951, grad RML1: 0.335839, ctrl RMAE: 0.184287
# validation errors:
# value RMAE: 2.470168, grad RML1: 1.893789, ctrl RMAE: 3.348422
#
# generalization loss: 0.011861
# training progress:   0.169136
#
# ------------------------------------
#  Epoch 84
# ------------------------------------
# total loss: 0.043320, value loss: 0.008937, grad loss: 0.000344 [    0/ 2467]
# total loss: 0.047794, value loss: 0.016285, grad loss: 0.000315 [ 1000/ 2467]
# total loss: 0.052024, value loss: 0.009187, grad loss: 0.000428 [ 2000/ 2467]
#
# training errors:
# value RMAE: 3.752604, grad RML1: 0.316864, ctrl RMAE: 0.157250
# validation errors:
# value RMAE: 2.292495, grad RML1: 1.881882, ctrl RMAE: 3.299011
#
# generalization loss: 0.000000
# training progress:   0.181494
#
# ------------------------------------
#  Epoch 85
# ------------------------------------
# total loss: 0.040316, value loss: 0.010920, grad loss: 0.000294 [    0/ 2467]
# total loss: 0.045756, value loss: 0.007537, grad loss: 0.000382 [ 1000/ 2467]
# total loss: 0.042578, value loss: 0.007236, grad loss: 0.000353 [ 2000/ 2467]
#
# training errors:
# value RMAE: 3.614652, grad RML1: 0.325848, ctrl RMAE: 0.165525
# validation errors:
# value RMAE: 2.323106, grad RML1: 1.895857, ctrl RMAE: 3.328960
#
# generalization loss: 0.009078
# training progress:   0.150056
#
# ------------------------------------
#  Epoch 86
# ------------------------------------
# total loss: 0.040161, value loss: 0.010022, grad loss: 0.000301 [    0/ 2467]
# total loss: 0.040295, value loss: 0.008616, grad loss: 0.000317 [ 1000/ 2467]
# total loss: 0.061970, value loss: 0.020545, grad loss: 0.000414 [ 2000/ 2467]
#
# training errors:
# value RMAE: 4.386099, grad RML1: 0.321266, ctrl RMAE: 0.150182
# validation errors:
# value RMAE: 2.261194, grad RML1: 1.873212, ctrl RMAE: 3.263738
#
# generalization loss: 0.000000
# training progress:   0.111573
#
# ------------------------------------
#  Epoch 87
# ------------------------------------
# total loss: 0.046809, value loss: 0.013118, grad loss: 0.000337 [    0/ 2467]
# total loss: 0.043099, value loss: 0.011245, grad loss: 0.000319 [ 1000/ 2467]
# total loss: 0.052431, value loss: 0.016932, grad loss: 0.000355 [ 2000/ 2467]
#
# training errors:
# value RMAE: 2.801635, grad RML1: 0.316450, ctrl RMAE: 0.208334
# validation errors:
# value RMAE: 2.462900, grad RML1: 1.902193, ctrl RMAE: 3.409977
#
# generalization loss: 0.044807
# training progress:   0.152704
#
# ------------------------------------
#  Adaptive Data Generation
# ------------------------------------
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 395 data points (from 211 initially guessed points)
# solution time:       4.282239 of which 2.552475 solving BVP
# solution time per data point: 0.010841
#
# data generated: 2862 / 3083
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 412 data points (from 209 initially guessed points)
# solution time:       4.270416 of which 2.433565 solving BVP
# solution time per data point: 0.010365
#
# data generated: 3274 / 3083
#
# ------------------------------------
#  Epoch 88
# ------------------------------------
# total loss: 0.395289, value loss: 0.012021, grad loss: 0.003833 [    0/ 3274]
# total loss: 0.716774, value loss: 0.036293, grad loss: 0.006805 [ 1000/ 3274]
# total loss: 0.359180, value loss: 0.011987, grad loss: 0.003472 [ 2000/ 3274]
# total loss: 0.309355, value loss: 0.013929, grad loss: 0.002954 [ 3000/ 3274]
#
# training errors:
# value RMAE: 7.026625, grad RML1: 0.774780, ctrl RMAE: 0.811373
# validation errors:
# value RMAE: 3.075122, grad RML1: 1.771175, ctrl RMAE: 2.811455
#
# generalization loss: 0.000000
# training progress:   0.987806
#
# ------------------------------------
#  Epoch 89
# ------------------------------------
# total loss: 0.320738, value loss: 0.030319, grad loss: 0.002904 [    0/ 3274]
# total loss: 0.137497, value loss: 0.022828, grad loss: 0.001147 [ 1000/ 3274]
# total loss: 0.159766, value loss: 0.010159, grad loss: 0.001496 [ 2000/ 3274]
# total loss: 0.148305, value loss: 0.012119, grad loss: 0.001362 [ 3000/ 3274]
#
# training errors:
# value RMAE: 3.616290, grad RML1: 0.563948, ctrl RMAE: 0.408546
# validation errors:
# value RMAE: 2.018408, grad RML1: 1.744419, ctrl RMAE: 2.828690
#
# generalization loss: 0.006130
# training progress:   1.322460
#
# ------------------------------------
#  Epoch 90
# ------------------------------------
# total loss: 0.105932, value loss: 0.012709, grad loss: 0.000932 [    0/ 3274]
# total loss: 0.099620, value loss: 0.013379, grad loss: 0.000862 [ 1000/ 3274]
# total loss: 0.084317, value loss: 0.014620, grad loss: 0.000697 [ 2000/ 3274]
# total loss: 0.095717, value loss: 0.011310, grad loss: 0.000844 [ 3000/ 3274]
#
# training errors:
# value RMAE: 6.977781, grad RML1: 0.491173, ctrl RMAE: 0.264648
# validation errors:
# value RMAE: 3.085004, grad RML1: 1.675577, ctrl RMAE: 2.631140
#
# generalization loss: 0.000000
# training progress:   1.454464
#
# ------------------------------------
#  Epoch 91
# ------------------------------------
# total loss: 0.100043, value loss: 0.032638, grad loss: 0.000674 [    0/ 3274]
# total loss: 0.075235, value loss: 0.014259, grad loss: 0.000610 [ 1000/ 3274]
# total loss: 0.076237, value loss: 0.009715, grad loss: 0.000665 [ 2000/ 3274]
# total loss: 0.061567, value loss: 0.009032, grad loss: 0.000525 [ 3000/ 3274]
#
# training errors:
# value RMAE: 4.017724, grad RML1: 0.453867, ctrl RMAE: 0.251171
# validation errors:
# value RMAE: 1.986158, grad RML1: 1.694950, ctrl RMAE: 2.680037
#
# generalization loss: 0.018584
# training progress:   0.866299
#
# ------------------------------------
#  Epoch 92
# ------------------------------------
# total loss: 0.054827, value loss: 0.011120, grad loss: 0.000437 [    0/ 3274]
# total loss: 0.094095, value loss: 0.026648, grad loss: 0.000674 [ 1000/ 3274]
# total loss: 0.058652, value loss: 0.008300, grad loss: 0.000504 [ 2000/ 3274]
# total loss: 0.058568, value loss: 0.013248, grad loss: 0.000453 [ 3000/ 3274]
#
# training errors:
# value RMAE: 2.563561, grad RML1: 0.423730, ctrl RMAE: 0.283424
# validation errors:
# value RMAE: 2.005258, grad RML1: 1.658008, ctrl RMAE: 2.656703
#
# generalization loss: 0.009716
# training progress:   0.607799
#
# ------------------------------------
#  Epoch 93
# ------------------------------------
# total loss: 0.050747, value loss: 0.007231, grad loss: 0.000435 [    0/ 3274]
# total loss: 0.072213, value loss: 0.011888, grad loss: 0.000603 [ 1000/ 3274]
# total loss: 0.066786, value loss: 0.011656, grad loss: 0.000551 [ 2000/ 3274]
# total loss: 0.073423, value loss: 0.016901, grad loss: 0.000565 [ 3000/ 3274]
#
# training errors:
# value RMAE: 4.554842, grad RML1: 0.398037, ctrl RMAE: 0.230856
# validation errors:
# value RMAE: 2.176556, grad RML1: 1.630386, ctrl RMAE: 2.580089
#
# generalization loss: 0.000000
# training progress:   0.246356
#
# ------------------------------------
#  Epoch 94
# ------------------------------------
# total loss: 0.047980, value loss: 0.011693, grad loss: 0.000363 [    0/ 3274]
# total loss: 0.056948, value loss: 0.005372, grad loss: 0.000516 [ 1000/ 3274]
# total loss: 0.044988, value loss: 0.006442, grad loss: 0.000385 [ 2000/ 3274]
# total loss: 0.058489, value loss: 0.007962, grad loss: 0.000505 [ 3000/ 3274]
#
# training errors:
# value RMAE: 4.004576, grad RML1: 0.416605, ctrl RMAE: 0.304348
# validation errors:
# value RMAE: 3.443728, grad RML1: 1.642528, ctrl RMAE: 2.641748
#
# generalization loss: 0.023898
# training progress:   0.156085
#
# ------------------------------------
#  Adaptive Data Generation
# ------------------------------------
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 401 data points (from 210 initially guessed points)
# solution time:       4.286771 of which 2.451849 solving BVP
# solution time per data point: 0.010690
#
# data generated: 3675 / 4092
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 405 data points (from 209 initially guessed points)
# solution time:       4.436389 of which 2.473824 solving BVP
# solution time per data point: 0.010954
#
# data generated: 4080 / 4092
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 416 data points (from 211 initially guessed points)
# solution time:       4.163231 of which 2.503001 solving BVP
# solution time per data point: 0.010008
#
# data generated: 4496 / 4092
#
# ------------------------------------
#  Epoch 95
# ------------------------------------
# total loss: 0.660544, value loss: 0.039483, grad loss: 0.006211 [    0/ 4496]
# total loss: 0.576883, value loss: 0.031520, grad loss: 0.005454 [ 1000/ 4496]
# total loss: 0.370417, value loss: 0.020396, grad loss: 0.003500 [ 2000/ 4496]
# total loss: 0.659893, value loss: 0.027169, grad loss: 0.006327 [ 3000/ 4496]
# total loss: 0.308876, value loss: 0.009796, grad loss: 0.002991 [ 4000/ 4496]
#
# training errors:
# value RMAE: 6.389324, grad RML1: 0.759767, ctrl RMAE: 0.763890
# validation errors:
# value RMAE: 4.800167, grad RML1: 1.595051, ctrl RMAE: 2.409721
#
# generalization loss: 0.000000
# training progress:   0.588598
#
# ------------------------------------
#  Epoch 96
# ------------------------------------
# total loss: 0.285673, value loss: 0.034719, grad loss: 0.002510 [    0/ 4496]
# total loss: 0.328606, value loss: 0.049357, grad loss: 0.002792 [ 1000/ 4496]
# total loss: 0.145647, value loss: 0.020930, grad loss: 0.001247 [ 2000/ 4496]
# total loss: 0.197282, value loss: 0.010797, grad loss: 0.001865 [ 3000/ 4496]
# total loss: 0.160830, value loss: 0.008315, grad loss: 0.001525 [ 4000/ 4496]
#
# training errors:
# value RMAE: 2.676476, grad RML1: 0.630272, ctrl RMAE: 0.422226
# validation errors:
# value RMAE: 1.686724, grad RML1: 1.506889, ctrl RMAE: 2.163228
#
# generalization loss: 0.000000
# training progress:   0.736789
#
# ------------------------------------
#  Epoch 97
# ------------------------------------
# total loss: 0.190891, value loss: 0.006493, grad loss: 0.001844 [    0/ 4496]
# total loss: 0.143579, value loss: 0.005788, grad loss: 0.001378 [ 1000/ 4496]
# total loss: 0.116145, value loss: 0.006859, grad loss: 0.001093 [ 2000/ 4496]
# total loss: 0.105497, value loss: 0.009516, grad loss: 0.000960 [ 3000/ 4496]
# total loss: 0.113727, value loss: 0.025752, grad loss: 0.000880 [ 4000/ 4496]
#
# training errors:
# value RMAE: 2.445942, grad RML1: 0.552459, ctrl RMAE: 0.439354
# validation errors:
# value RMAE: 2.182601, grad RML1: 1.380461, ctrl RMAE: 2.036103
#
# generalization loss: 0.000000
# training progress:   0.871878
#
# ------------------------------------
#  Epoch 98
# ------------------------------------
# total loss: 0.106341, value loss: 0.006514, grad loss: 0.000998 [    0/ 4496]
# total loss: 0.080622, value loss: 0.008942, grad loss: 0.000717 [ 1000/ 4496]
# total loss: 0.161325, value loss: 0.062552, grad loss: 0.000988 [ 2000/ 4496]
# total loss: 0.116967, value loss: 0.007007, grad loss: 0.001100 [ 3000/ 4496]
# total loss: 0.082028, value loss: 0.012153, grad loss: 0.000699 [ 4000/ 4496]
#
# training errors:
# value RMAE: 2.095303, grad RML1: 0.506971, ctrl RMAE: 0.330920
# validation errors:
# value RMAE: 1.540051, grad RML1: 1.366805, ctrl RMAE: 1.982572
#
# generalization loss: 0.000000
# training progress:   0.485626
#
# ------------------------------------
#  Epoch 99
# ------------------------------------
# total loss: 0.073023, value loss: 0.005156, grad loss: 0.000679 [    0/ 4496]
# total loss: 0.074361, value loss: 0.005399, grad loss: 0.000690 [ 1000/ 4496]
# total loss: 0.092525, value loss: 0.007225, grad loss: 0.000853 [ 2000/ 4496]
# total loss: 0.100709, value loss: 0.032445, grad loss: 0.000683 [ 3000/ 4496]
# total loss: 0.123615, value loss: 0.004894, grad loss: 0.001187 [ 4000/ 4496]
#
# training errors:
# value RMAE: 2.006535, grad RML1: 0.513174, ctrl RMAE: 0.274806
# validation errors:
# value RMAE: 1.467710, grad RML1: 1.348961, ctrl RMAE: 1.857645
#
# generalization loss: 0.000000
# training progress:   0.623832
#
# ------------------------------------
#  Epoch 100
# ------------------------------------
# total loss: 0.109292, value loss: 0.005535, grad loss: 0.001038 [    0/ 4496]
# total loss: 0.071760, value loss: 0.014635, grad loss: 0.000571 [ 1000/ 4496]
# total loss: 0.122282, value loss: 0.041447, grad loss: 0.000808 [ 2000/ 4496]
# total loss: 0.062813, value loss: 0.005497, grad loss: 0.000573 [ 3000/ 4496]
# total loss: 0.108650, value loss: 0.029060, grad loss: 0.000796 [ 4000/ 4496]
#
# training errors:
# value RMAE: 3.781395, grad RML1: 0.495096, ctrl RMAE: 0.258380
# validation errors:
# value RMAE: 2.186920, grad RML1: 1.298519, ctrl RMAE: 1.756162
#
# generalization loss: 0.000000
# training progress:   0.335774
#
# ------------------------------------
#  Epoch 101
# ------------------------------------
# total loss: 0.094769, value loss: 0.011258, grad loss: 0.000835 [    0/ 4496]
# total loss: 0.074772, value loss: 0.005981, grad loss: 0.000688 [ 1000/ 4496]
# total loss: 0.066966, value loss: 0.007536, grad loss: 0.000594 [ 2000/ 4496]
# total loss: 0.064507, value loss: 0.003747, grad loss: 0.000608 [ 3000/ 4496]
# total loss: 0.059849, value loss: 0.004579, grad loss: 0.000553 [ 4000/ 4496]
#
# training errors:
# value RMAE: 1.928625, grad RML1: 0.437275, ctrl RMAE: 0.256226
# validation errors:
# value RMAE: 1.429933, grad RML1: 1.289803, ctrl RMAE: 1.801411
#
# generalization loss: 0.025766
# training progress:   0.217432
#
# ------------------------------------
#  Adaptive Data Generation
# ------------------------------------
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 420 data points (from 211 initially guessed points)
# solution time:       4.777985 of which 2.736651 solving BVP
# solution time per data point: 0.011376
#
# data generated: 4916 / 5620
#
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 414 data points (from 210 initially guessed points)
# solution time:       4.703807 of which 2.745434 solving BVP
# solution time per data point: 0.011362
#
# data generated: 5330 / 5620
#
# Training terminated: maximum time limit is exceeded

# %% [markdown]
# ### Restarting notebook

# %%
# option to restart notebook here
restart = False
if restart:
    import numpy as np
    import torch
    from torch import nn
    from torch.utils.data import DataLoader
    import matplotlib.pyplot as plt
    # %matplotlib inline
    import time
    import warnings
    import os
    
    import OCP
    import BVP
    import data_generation
    import NN
    import NN_optimization
    
    problem_type = 'HighDimBilinCtrlZeroTarget'; model_type = 'ResidualForcedFinalConditionNet'; train_type = 'AdamTimeStopped'
    partial_train_times = [float('inf')]
    
    problem = OCP.load_problem(problem_type)
    training = NN_optimization.load_training(problem_type, model_type, train_type)

# %% [markdown]
# ### Visualization of training phase

# %%
# plot errors, data set size and runtime in training phase
training.plot_training_phase(save=True, problem_type=problem_type, model_type=model_type, train_type=train_type)

# display training statistics
training.display_stats(save=True, problem_type=problem_type, model_type=model_type, train_type=train_type)
# Out:
# ------------------------------------
#  Training Statistics
# ------------------------------------
# total training time:           101.240104
# total number of training data: 4496
#
# data generation occured at epochs 50, 71, 87, 94 with ratio 1.249802, 1.249849, 1.249696, 1.249847
# total epochs: 101, optimal epoch: 100
#
# training errors of optimal model:
# value RMAE: 3.781395, grad RML1: 0.495096, ctrl RMAE: 0.258380
# validation errors of optimal model:
# value RMAE: 2.186920, grad RML1: 1.298519, ctrl RMAE: 1.756162

# %% [markdown]
# ### Testing  model

# %%
# choose number of trajectories in test set
num_test_samples = 10

# load optimal model parameters
model = NN.load_model(problem_type, model_type, train_type)

# generate test data using NN warm start
X0_samples = data_generation.sample_X0(problem, num_samples=num_test_samples)
print('------------------------------------\n Test Data Generation\n------------------------------------')
with warnings.catch_warnings():
    warnings.simplefilter('once')
    t_data, X_aug_data, idx_samples, _ = BVP.solve_BVP(problem, X0_samples, initialization='NN_warm_start', 
                                                       init_config={'model':model})
data_generation.save_data(t_data, X_aug_data, idx_samples, problem_type, 'test')

# compute test accuracy
test_data = data_generation.OCPDataset(problem_type, 'test')
if training.batch_size == 'full':
    test_dataloader = DataLoader(test_data, batch_size=len(test_data))
else:
    test_dataloader = DataLoader(test_data, batch_size=training.batch_size, shuffle=True)
print('------------------------------------\n Test Statistics\n------------------------------------')
print('test errors of optimal model:')
training.test_errors = np.hstack((training.test_errors, training.validate(test_dataloader, problem, model)))
training.add_test_stats(problem_type=problem_type, model_type=model_type, train_type=train_type)
# Out:
# ------------------------------------
#  Test Data Generation
# ------------------------------------
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 10 generating 3999 data points (from 2099 initially guessed points)
# solution time:       43.970268 of which 24.975853 solving BVP
# solution time per data point: 0.010995
#
# ------------------------------------
#  Test Statistics
# ------------------------------------
# test errors of optimal model:
# value RMAE: 4.200455, grad RML1: 1.454278, ctrl RMAE: 2.406100

# %% [markdown]
# ### Properties of data sets

# %%
# display properties of data sets
print('------------------------------------\n Training Data Set\n------------------------------------')
data_generation.add_dataset_stats(problem_type, 'train', save=True, model_type=model_type, train_type=train_type)

print('------------------------------------\n Validation Data Set\n------------------------------------')
data_generation.add_dataset_stats(problem_type, 'val', save=True, model_type=model_type, train_type=train_type)

print('------------------------------------\n Test Data Set\n------------------------------------')
data_generation.add_dataset_stats(problem_type, 'test', save=True, model_type=model_type, train_type=train_type)
# Out:
# ------------------------------------
#  Training Data Set
# ------------------------------------
# number of trajectories: 15, number of data points: 5330
#
# ------------------------------------
#  Validation Data Set
# ------------------------------------
# number of trajectories: 5, number of data points: 1255
#
# ------------------------------------
#  Test Data Set
# ------------------------------------
# number of trajectories: 10, number of data points: 3999

# %% [markdown]
# ### Simulation of NN, BVP, LQR solutions and uncontrolled system for specific initial condition

# %%
# name specific initial condition
init_type = 'sin'

# choose specific initial condition
#initial_condition = OCP.zero
#initial_condition = OCP.quadratic
#initial_condition = OCP.polynomial
initial_condition = OCP.sin
#initial_condition = OCP.quadratic_cos

# option to multiply initial condition with factor (scale or flip sign)
scale_factor = 1.

specific_X0 = scale_factor * initial_condition(problem.Omega_mesh[1:-1]).reshape(-1,1)

# get target
Y = problem.target(problem.Omega_mesh[1:-1]).reshape(-1,1)

# decide on methods for comparison (bilinear control does not allow for LQR)
methods = ['NN', 'LQR', 'BVP', 'unctrl'] 
if problem.ctrl == 'bilin' and 'LQR' in methods:
    methods.remove('LQR')

# %%
import NN_evaluation
import LQR
import simulation

# compute closed-loop NN solution
if 'NN' in methods:
    t_NN, X_NN = NN_evaluation.get_trajectory(problem, model, specific_X0)
    V_NN, P_NN, U_NN = NN_evaluation.get_data(model, t_NN, X_NN, get_U=True, problem=problem)

# compute closed-loop LQR solution
if 'LQR' in methods:
    if problem.target == OCP.zero:
        LQ_problem = LQR.LQProblem(problem)
    else:
        LQ_problem = LQR.LQProblemNonzeroTarget(problem)
    t_LQR, X_LQR = LQ_problem.get_trajectory(specific_X0)
    V_LQR, P_LQR, U_LQR = LQ_problem.get_data(t_LQR, X_LQR)
    
# compute open-loop BVP solution
if 'BVP' in methods:
    print('------------------------------------\n Specific Example Data Generation\n------------------------------------') 
    solver_config = {'max_nodes':5000, 'tol':1e-5, 'replace_sample':False}
    t_BVP, X_aug_BVP, _, X_aug_funs = BVP.solve_BVP(problem, specific_X0, initialization='NN_warm_start',
                                            init_config={'model':model}, solver_config=solver_config)
    X_BVP, V_BVP, P_BVP, U_BVP = data_generation.split_data(X_aug_BVP, get_U=True, problem=problem)
    
# compute uncontrolled dynamics 
if 'unctrl' in methods:
    ctrl = problem.ctrl
    problem.ctrl = None  
    print('--- Uncontrolled System ---')
    init_config = {'timeseq':np.array([0, 1e-03, 1e-02, .1, .125, .15, .2, .3, .4, .5, .6, .7, .8, .9, 1.])}
    solver_config = {'max_nodes':5000, 'tol':1e-5, 'replace_sample':False}
    t_unctrl, X_aug_unctrl, _, _ = BVP.solve_BVP(problem, specific_X0, initialization='time_marching', 
                                                 init_config=init_config, solver_config=solver_config)
    X_unctrl, V_unctrl, P_unctrl, U_unctrl = data_generation.split_data(X_aug_unctrl, get_U=True, problem=problem)
    if not len(t_unctrl):
        methods.remove('unctrl')
    problem.ctrl = ctrl
# Out:
# ------------------------------------
#  Specific Example Data Generation
# ------------------------------------
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 1 generating 227 data points (from 204 initially guessed points)
# solution time:       2.968104 of which 1.108460 solving BVP
# solution time per data point: 0.013075
#
# --- Uncontrolled System ---
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:92: RuntimeWarning: overflow encountered in square
#   R = self.b*X**2
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:171: RuntimeWarning: overflow encountered in multiply
#   dRdx = 2*self.b*P*X
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:125: RuntimeWarning: overflow encountered in square
#   return self.alpha*self.mesh_size*np.sum((X-Y)**2, axis=0, keepdims=True)
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:309: RuntimeWarning: invalid value encountered in subtract
#   0.125 * h * (f[:, 1:] - f[:, :-1]))
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:311: RuntimeWarning: invalid value encountered in add
#   col_res = y[:, 1:] - y[:, :-1] - h / 6 * (f[:, :-1] + f[:, 1:] +
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:312: RuntimeWarning: overflow encountered in multiply
#   4 * f_middle)
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:145: RuntimeWarning: overflow encountered in square
#   return self.gamma*self.mesh_size*np.sum((X_tf-Y)**2)
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:40: RuntimeWarning: invalid value encountered in subtract
#   df_dy[:, i, :] = (f_new - f0) / hi
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:37: RuntimeWarning: invalid value encountered in add
#   y_new[i] += h[i]
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:38: RuntimeWarning: invalid value encountered in subtract
#   hi = y_new[i] - y[i]
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:88: RuntimeWarning: invalid value encountered in subtract
#   dbc_dya[i] = (bc_new - bc0) / hi
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:98: RuntimeWarning: invalid value encountered in subtract
#   dbc_dyb[i] = (bc_new - bc0) / hi
# number of fails:     1
# fail time:           7.993058
#
# number of solutions: 0 generating 0 data points (from 0 initially guessed points)
# solution time:       0.000000 of which 0.000000 solving BVP
# solution time per data point: nan
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:592: RuntimeWarning: invalid value encountered in add
#   t = (yp[:, :-1] + yp[:, 1:] - 2 * slope) / h
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:593: RuntimeWarning: overflow encountered in true_divide
#   c[0] = t / h
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:594: RuntimeWarning: overflow encountered in subtract
#   c[1] = (slope - yp[:, :-1]) / h - t
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:566: RuntimeWarning: invalid value encountered in true_divide
#   r_middle /= 1 + np.abs(f_middle)
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:567: RuntimeWarning: invalid value encountered in true_divide
#   r1 /= 1 + np.abs(f1)
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:568: RuntimeWarning: invalid value encountered in true_divide
#   r2 /= 1 + np.abs(f2)
# /home/eg/Desktop/Masterarbeit/programs/BVP.py:81: RuntimeWarning: A singular Jacobian encountered when solving the collocation system.
#   warnings.warn(sol.message, RuntimeWarning)
# /home/eg/Desktop/Masterarbeit/programs/BVP.py:165: RuntimeWarning: invalid value encountered in double_scalars
#   print(f'solution time per data point: {np.sum(solution_times)/len(t_data):<7f}\n')

# %%
# create directory for saving results
directory = simulation.get_directory(problem_type, model_type, train_type, init_type)

# plot optimal state trajectory
fig = plt.figure()
fig.suptitle('Optimal state trajectory', y=0.9)
axs = []
for num, method in enumerate(methods):                         
    axs.append(fig.add_subplot(1, len(methods), num + 1, projection='3d'))
    simulation.plot_X(eval('t_' + method), problem.Omega_mesh, eval('X_' + method), ax=axs[num])
    axs[num].set_title(method)
    axs[num].set_zlim(-1.,1.)
plt.subplots_adjust(left=0., bottom=0., right=1., top=1., wspace=0.6, hspace=0.0)
plt.savefig(directory + '/state.png', bbox_inches='tight')
plt.show()

# plot optimal costate trajectory
fig = plt.figure()
fig.suptitle('Optimal costate trajectory', y=0.9)
axs = []
for num, method in enumerate(methods):                         
    axs.append(fig.add_subplot(1, len(methods), num + 1, projection='3d'))
    simulation.plot_P(eval('t_' + method), problem.Omega_mesh, eval('P_' + method), ax=axs[num])
    axs[num].set_title(method)
    axs[num].set_zlim(-0.1,0.1)
plt.subplots_adjust(left=0., bottom=0., right=1., top=1., wspace=0.6, hspace=0.0)
plt.savefig(directory + '/costate.png', bbox_inches='tight')
plt.show()

# plot optimal control
fig = plt.figure()
fig.suptitle('Optimal control')
for method in methods:                         
    simulation.plot_U(eval('t_' + method), eval('U_' + method), label=method)
#plt.ylim(bottom=-5)
plt.legend()
plt.savefig(directory + '/control.png')
plt.show()

# plot value function along optimal state trajectory 
fig = plt.figure()
fig.suptitle('Value function along optimal state trajectory')
for method in methods:                         
    simulation.plot_V(eval('t_' + method), eval('V_' + method), label=method)
#plt.ylim(top=2.5)
plt.legend()
plt.savefig(directory + '/value_function.png')
plt.show()

# plot running cost resulting from optimal control and state trajectory 
fig = plt.figure()
fig.suptitle('Running cost resulting from optimal control and state trajectory', y=1.03)
for num, method in enumerate(methods):                         
    simulation.plot_running_cost(problem, eval('t_' + method), eval('U_' + method), eval('X_' + method), Y, 
                                 color='C' + str(num), label=method)
#plt.ylim(-1,5)
legend = plt.legend()
solid_line, = plt.plot([0],linestyle='-', color='gray')
dashed_line, = plt.plot([0],linestyle='--', color='gray')
dotted_line, = plt.plot([0],linestyle=':', color='gray')
legend_lines = plt.legend([solid_line, dashed_line, dotted_line], ['total running cost', 'running state cost', 'running control cost'], 
                          bbox_to_anchor=(0, 1.01, 1, 0.2), loc='lower left', mode='expand', borderaxespad=0, ncol=3)
plt.gca().add_artist(legend)
plt.gca().add_artist(legend_lines)
plt.savefig(directory + '/running_cost.png')
plt.show()

# display costs
for num, method in enumerate(methods): 
    append = False if num == 0 else True
    simulation.display_costs(problem, eval('t_' + method), eval('U_' + method), eval('X_' + method), Y, 
                             method=method, save=True, append=append, 
                             problem_type=problem_type, model_type=model_type, train_type=train_type, init_type=init_type)
# Out:
# ------------------------------------
#  Costs of NN Solution
# ------------------------------------
# running state cost:   0.124917
# running control cost: 0.149451
# total running cost:   0.274368
# final cost:           0.001745
# total cost:           0.276113
#
# ------------------------------------
#  Costs of BVP Solution
# ------------------------------------
# running state cost:   0.156186
# running control cost: 0.096383
# total running cost:   0.252569
# final cost:           0.002427
# total cost:           0.254996

# %% [markdown]
# ### Testing BVP initialization for data generation

# %%
# sample initial conditions
X0_samples = data_generation.sample_X0(problem, num_samples=10)
solver_config = {'max_nodes':5000, 'tol':1e-5, 'replace_sample':False}

# test simple initialization
print('------------------------------------\n Simple Initialization\n------------------------------------')
_ = BVP.solve_BVP(problem, X0_samples, solver_config=solver_config)
#print('\n--- Increased time steps ---')
#_ = BVP.solve_BVP(problem, X0_samples, init_config={'timesteps':100}, solver_config=solver_config)

# test time-marching
print('------------------------------------\n Time-Marching\n------------------------------------')
_ = BVP.solve_BVP(problem, X0_samples, initialization='time_marching', solver_config=solver_config)
print('\n--- Adaptive time sequence ---')
_ = BVP.solve_BVP(problem, X0_samples, initialization='time_marching', 
                  init_config={'timeseq':np.array([0, 1e-03, 1e-02, .1, .125, .15, .2, .3, .4, .5, .6, .7, .8, .9, 1.])}, 
                  solver_config=solver_config)
print('\n--- Equidistant time sequences with increased time steps ---')
_ = BVP.solve_BVP(problem, X0_samples, initialization='time_marching', 
                  init_config={'timeseq':30}, solver_config=solver_config)
#print('\n--- Equidistant time sequences with decreased time steps ---')
#_ = BVP.solve_BVP(problem, X0_samples, initialization='time_marching', 
#                  init_config={'timeseq':5}, solver_config=solver_config)

# test NN warm start
print('------------------------------------\n NN Warm Start\n------------------------------------') 
_ = BVP.solve_BVP(problem, X0_samples, initialization='NN_warm_start', 
                  init_config={'model':model}, solver_config=solver_config)

# test NN warm start with partially trained models
for partial_train_time in partial_train_times[:-1]:
    partial_train_type = train_type + 'PartialTrain' + str(partial_train_time)
    directory = NN.get_directory(problem_type, model_type, partial_train_type, make=False)
    if os.path.exists(directory):
        print(f'\n--- Partially trained model after time {partial_train_time} ---')
        partial_train_model = NN.load_model(problem_type, model_type, partial_train_type)
        _ = BVP.solve_BVP(problem, X0_samples, initialization='NN_warm_start', init_config={'model':partial_train_model}, solver_config=solver_config)
# Out:
# ------------------------------------
#  Simple Initialization
# ------------------------------------
# /home/eg/Desktop/Masterarbeit/programs/BVP.py:122: RuntimeWarning: The maximum number of mesh nodes is exceeded.
#   warnings.warn(sol.message, RuntimeWarning)
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:158: RuntimeWarning: overflow encountered in matmul
#   U = -self.c/(2*self.beta) * np.diag(P.T @ X).reshape((1,-1))
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:92: RuntimeWarning: overflow encountered in square
#   R = self.b*X**2
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:102: RuntimeWarning: overflow encountered in multiply
#   S = self.c*U*X
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:104: RuntimeWarning: invalid value encountered in add
#   return self.Q @ X + R + S
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:171: RuntimeWarning: overflow encountered in multiply
#   dRdx = 2*self.b*P*X
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:179: RuntimeWarning: overflow encountered in multiply
#   dSdx = self.c*U*P
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:181: RuntimeWarning: invalid value encountered in add
#   return 2*self.alpha*self.mesh_size * (X-Y) + self.Q.T @ P + dRdx + dSdx
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:125: RuntimeWarning: overflow encountered in square
#   return self.alpha*self.mesh_size*np.sum((X-Y)**2, axis=0, keepdims=True)
# /home/eg/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:129: RuntimeWarning: overflow encountered in square
#   return self.beta*U**2
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:312: RuntimeWarning: overflow encountered in multiply
#   4 * f_middle)
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:40: RuntimeWarning: invalid value encountered in subtract
#   df_dy[:, i, :] = (f_new - f0) / hi
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:566: RuntimeWarning: invalid value encountered in true_divide
#   r_middle /= 1 + np.abs(f_middle)
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:567: RuntimeWarning: invalid value encountered in true_divide
#   r1 /= 1 + np.abs(f1)
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:568: RuntimeWarning: invalid value encountered in true_divide
#   r2 /= 1 + np.abs(f2)
# /home/eg/Desktop/Masterarbeit/programs/BVP.py:122: RuntimeWarning: A singular Jacobian encountered when solving the collocation system.
#   warnings.warn(sol.message, RuntimeWarning)
# /home/eg/Desktop/Masterarbeit/programs/OCP.py:158: RuntimeWarning: invalid value encountered in matmul
#   U = -self.c/(2*self.beta) * np.diag(P.T @ X).reshape((1,-1))
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:38: RuntimeWarning: invalid value encountered in subtract
#   hi = y_new[i] - y[i]
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:593: RuntimeWarning: overflow encountered in true_divide
#   c[0] = t / h
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:563: RuntimeWarning: invalid value encountered in subtract
#   r1 = y1_prime - f1
# /home/eg/anaconda3/lib/python3.9/site-packages/scipy/integrate/_bvp.py:564: RuntimeWarning: invalid value encountered in subtract
#   r2 = y2_prime - f2
# number of fails:     4
# fail time:           83.322230
#
# number of solutions: 6 generating 4869 data points (from 180 initially guessed points)
# solution time:       49.184443 of which 49.183672 solving BVP
# solution time per data point: 0.010102
#
# ------------------------------------
#  Time-Marching
# ------------------------------------
# /home/eg/Desktop/Masterarbeit/programs/BVP.py:81: RuntimeWarning: The maximum number of mesh nodes is exceeded.
#   warnings.warn(sol.message, RuntimeWarning)
# /home/eg/Desktop/Masterarbeit/programs/BVP.py:81: RuntimeWarning: A singular Jacobian encountered when solving the collocation system.
#   warnings.warn(sol.message, RuntimeWarning)
# number of fails:     6
# fail time:           206.364359
#
# number of solutions: 4 generating 1010 data points (from 948 initially guessed points)
# solution time:       18.173670 of which 3.248143 solving BVP
# solution time per data point: 0.017994
#
#
# --- Adaptive time sequence ---
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 10 generating 2563 data points (from 2369 initially guessed points)
# solution time:       43.838097 of which 8.235723 solving BVP
# solution time per data point: 0.017104
#
#
# --- Equidistant time sequences with increased time steps ---
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 10 generating 2650 data points (from 2527 initially guessed points)
# solution time:       104.367365 of which 8.667689 solving BVP
# solution time per data point: 0.039384
#
# ------------------------------------
#  NN Warm Start
# ------------------------------------
# number of fails:     0
# fail time:           0.000000
#
# number of solutions: 10 generating 4015 data points (from 2097 initially guessed points)
# solution time:       44.841804 of which 25.505018 solving BVP
# solution time per data point: 0.011169
